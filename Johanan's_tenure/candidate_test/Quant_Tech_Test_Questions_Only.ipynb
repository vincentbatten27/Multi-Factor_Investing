# %% [markdown]
# # 🧪 Quant Tech Test – Candidate Version
# This version contains only the questions. Please write your answers in the code cells provided.

# %% [markdown]
# ## 🧮 Section 1: Math & Reasoning

# %% [markdown]
# **Q1.1**: What is the difference between mean and median?
#
# **Q1.2**: A stock has a daily return of 0.05% and daily volatility of 2%. Estimate the expected return and standard deviation over a year (252 trading days).
#
# **Q1.3**: What is a drawdown in the context of portfolio returns?

# %%
# Write your answers here for Q1.2 calculations

# %% [markdown]
# ## 💻 Section 2: Coding

# %% [markdown]
# **Q2.1**: Write a function to compute the cumulative return curve given a Series of daily returns.

# %%
def cumulative_return_curve(returns):
    # Your code here
    pass

# %% [markdown]
# **Q2.2**: Write a function to compute the maximum drawdown from a cumulative return curve.

# %%
def compute_max_drawdown(cum_returns):
    # Your code here
    pass

# %% [markdown]
# ## 📉 Section 3: Simulation

# %% [markdown]
# **Q3.1**: Simulate 1000 one-year return paths for a stock with daily return of 0.04% and daily volatility of 1%. Start from $1 and plot the 5th and 50th percentile of ending wealth.

# %%
# Write your simulation code here

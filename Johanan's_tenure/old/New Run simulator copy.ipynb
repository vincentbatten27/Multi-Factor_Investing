# %%
# To ignore all warnings
import warnings
warnings.filterwarnings("ignore")

# %%
download_libraries("check")
# Out:
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from seaborn) (2.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas_datareader in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.10.0)
# Requirement already satisfied: lxml in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas_datareader) (5.1.0)
# Requirement already satisfied: pandas>=0.23 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas_datareader) (2.2.0)
# Requirement already satisfied: requests>=2.19.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas_datareader) (2.31.0)
# Requirement already satisfied: numpy<2,>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=0.23->pandas_datareader) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=0.23->pandas_datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=0.23->pandas_datareader) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=0.23->pandas_datareader) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.19.0->pandas_datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.19.0->pandas_datareader) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.19.0->pandas_datareader) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.19.0->pandas_datareader) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas_datareader) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (1.4.0)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: getFamaFrenchFactors in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.0.5)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from getFamaFrenchFactors) (2.2.0)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from getFamaFrenchFactors) (2.31.0)
# Requirement already satisfied: bs4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from getFamaFrenchFactors) (0.0.2)
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bs4->getFamaFrenchFactors) (4.12.2)
# Requirement already satisfied: numpy<2,>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->getFamaFrenchFactors) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->getFamaFrenchFactors) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->getFamaFrenchFactors) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->getFamaFrenchFactors) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->getFamaFrenchFactors) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->getFamaFrenchFactors) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->getFamaFrenchFactors) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->getFamaFrenchFactors) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->getFamaFrenchFactors) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from beautifulsoup4->bs4->getFamaFrenchFactors) (2.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas-datareader in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.10.0)
# Requirement already satisfied: lxml in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas-datareader) (5.1.0)
# Requirement already satisfied: pandas>=0.23 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas-datareader) (2.2.0)
# Requirement already satisfied: requests>=2.19.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas-datareader) (2.31.0)
# Requirement already satisfied: numpy<2,>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=0.23->pandas-datareader) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=0.23->pandas-datareader) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=0.23->pandas-datareader) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.19.0->pandas-datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.19.0->pandas-datareader) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.19.0->pandas-datareader) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.19.0->pandas-datareader) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (1.4.0)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: plotly in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (5.18.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from plotly) (23.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipython in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (8.19.0)
# Requirement already satisfied: decorator in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython) (2.17.2)
# Requirement already satisfied: stack-data in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython) (5.14.0)
# Requirement already satisfied: pexpect>4.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipython) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython) (0.2.12)
# Requirement already satisfied: executing>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from stack-data->ipython) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from stack-data->ipython) (2.4.1)
# Requirement already satisfied: pure-eval in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from asttokens>=2.1.0->stack-data->ipython) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement random (from versions: none)
# ERROR: No matching distribution found for random
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: yfinance in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.2.36)
# Requirement already satisfied: pandas>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yfinance) (2.2.0)
# Requirement already satisfied: numpy>=1.16.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yfinance) (5.1.0)
# Requirement already satisfied: appdirs>=1.4.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yfinance) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: statsmodels in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.14.1)
# Requirement already satisfied: numpy<2,>=1.18 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from statsmodels) (1.12.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from statsmodels) (2.2.0)
# Requirement already satisfied: patsy>=0.5.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from statsmodels) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2023.4)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from patsy>=0.5.4->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pulp in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.8.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyarrow in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (15.0.0)
# Requirement already satisfied: numpy<2,>=1.16.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pyarrow) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (69.0.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: openpyxl in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
def download_libraries(command):
    if command=="check":
        # %pip install numpy
        # %pip install pandas
        # %pip install seaborn
        # %pip install matplotlib.pyplot
        # %pip install matplotlib
        # %pip install pandas_datareader
        # %pip install scikit-learn
        # %pip install getFamaFrenchFactors
        # %pip install matplotlib 
        # %pip install pandas-datareader 
        # %pip install scikit-learn 
        # %pip install plotly 
        # %pip install ipython 
        # %pip install random 
        # %pip install yfinance 
        # %pip install statsmodels 
        # %pip install pulp
        # %pip install pyarrow
        # %pip install setuptools
        # %pip install --upgrade certifi
        # %pip install openpyxl

# %%
import matplotlib.pyplot as plt
import numpy as np, numpy.random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
import calendar
from sklearn.linear_model import LinearRegression
import plotly.express as px
from IPython.display import Markdown as md
import random as rand
from matplotlib import gridspec
import yfinance as yf
from datetime import datetime
import getFamaFrenchFactors as gff
from pandas.tseries.offsets import DateOffset
from statsmodels.formula.api import ols
import statsmodels.api as sm
import random
yf.pdr_override()
import pulp
from sklearn.preprocessing import LabelEncoder
import pandas_datareader.data as reader
import yfinance as yf
import pandas as pd
import requests
import getFamaFrenchFactors as gff
from pulp import LpProblem, LpMaximize, LpVariable, LpMinimize, LpBinary, lpSum
from pulp import *

# %%
def get_spy(beta1,beta2,beta3,start,end):
  
    global tickers
    requests.packages.urllib3.disable_warnings() 
    # Fetch HTML content
    response = requests.get('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies', verify=False)
    html_content = response.content
    # Read HTML content into pandas DataFrame
    list_of_dfs = pd.read_html(html_content)
    wikitable_sp_500 = list_of_dfs[0]
    sp500_symbols = wikitable_sp_500['Symbol']#Converting SP_500 tickers into list 
    tickers = sp500_symbols.to_list()#Remove some tickers as they create an error for the yfinance api
    tickers[65] = 'BRK-B'
    tickers[81] = 'BF-B'
    tickers.remove('BF-B')
    tickers.remove('BRK-B')#Start Date for In Sample Historical Data
    global monthly_data
    global base_w
    monthly_data = yf.download(tickers,start=start,end=end,interval='1mo')#Reformat Date Index 
    monthly_data.index = pd.to_datetime(monthly_data.index)
    monthly_data = monthly_data.tz_localize(None)#Turn Adj Close prices into pct returns
    monthly_data = monthly_data['Adj Close'].pct_change()#Drop First row NaN values
    monthly_data = monthly_data.drop(monthly_data.index[0])#Drop if stock doesnt have data starting from the first index date
    monthly_data = monthly_data.dropna(axis=1)#Assign equal weight as base weights
    
    base_w = {k: 1/len(monthly_data.columns) for k in monthly_data.columns}
    base_w = pd.DataFrame.from_dict(base_w, orient='index', columns=['Weight'])#Getting SP_500 data
    spy = pd.DataFrame(yf.download('^GSPC',start=start,end=end,interval='1mo')['Adj Close'].pct_change())#Dropping First Row(NaN) and formatting index to match monthly_data 
    spy = spy.drop(spy.index[0]).tz_localize(None)#Adding SP_500 data to monthly_data
    monthly_data['SP_500'] = spy['Adj Close']
    #Adjusting tickers list as some tickers will not be included in the monthly_data if there is no data for test date range
    
    tickers = list(monthly_data.columns[:-1])
    tick_index = tickers + ['SP_500']

# %%
def famafrenchreturns():
    global ff3_monthly
    # Fama French Monthly Returns Data using getFamaFrenchFactors module
    ff3_monthly = gff.famaFrench3Factor(frequency='m')
    ff3_monthly.rename(columns={"date_ff_factors": 'Date'}, inplace=True)
    ff3_monthly.set_index('Date', inplace=True)
    ff3_monthly.index = ff3_monthly.index.to_period('M').to_timestamp('D')
    # Keeping Only the Dates in the monthly_data
    ff3_monthly = ff3_monthly.loc[monthly_data.index]

# %%
def to__cal_stock_betas():
    global stock_betas
    stock_betas = pd.DataFrame()
    # Iterate over the tickers list
    for col in monthly_data.columns:
        # Set the dependent variable (Return of stock i)
        y = monthly_data[col]
        # Set the independent variables (Fama French 3 Factors)
        X = ff3_monthly[['Mkt-RF','SMB','HML']]
        # Fit the multiple linear regression model
        model = LinearRegression()
        model.fit(X, y)
        # Store the results in the DataFrame
        stock_betas[col] = [model.intercept_] + list(model.coef_)
    stock_betas = stock_betas.T
    stock_betas.columns = ['Intercept','Mkt-RF','SMB','HML']

# %%
def to_cal_stock_price():
    global stock_price
    global s_price
    global s_keys
    global s_values
    #Stock Prices on the Day of Optimization(Rebalancing)
    stock_price = pd.DataFrame(yf.download(tickers,start=start,end=end,interval='1d')['Adj Close'])
    stock_price = stock_price[-1:]
    stock_price.index = pd.to_datetime(stock_price.index).tz_localize(None)
    s_price = {}
    s_keys = list(tickers)
    s_values =  list(stock_price.iloc[0])
    for key,value in zip(s_keys,s_values):
        s_price[key] = value

# %%
def Transaction_Costs():
    #Transaction_Costs
    random.seed(1)
    global t_cost
    t_cost = {}
    global keys
    keys = list(tickers)
    #values     = [.15 for i in range(len(keys))] 
    values = list(random.uniform(.01,.02) for i in range(len(tickers)))
    for key,value in zip(keys,values):
        t_cost[key] = value

# %%
def optimization():
# OPTIMIZATION MODEL
    global index
    global wei
    global aux
    global err
    global binary
    global tr_cost
    global shares
    index = LpProblem('Index', LpMinimize) 
    # Decision Variables
    wei = LpVariable.dicts('Weight',tickers,lowBound=0)                           # Weights for stock i in the optimal portfolio
    aux = LpVariable.dicts('Y',tickers,lowBound=0)                                # Absolute value of change for stock i from base weights
    err = LpVariable.dicts('Error', monthly_data.index, lowBound=0)               # Error term for portfolio
    binary = LpVariable.dicts('bin',tickers,cat=LpBinary)                         # Used if we want to limit the # of stocks we want to have in optimal portfolio
    tr_cost = LpVariable.dicts('Transaction_Cost',tickers,lowBound=0)             # Total Transaction cost for stock i in the optimal portfolio
    shares = LpVariable.dicts('shares',tickers,lowBound=0)                        # Total Transaction cost for stock i in the optimal portfolio
    #Objective Function - Minimize the error term 
    index +=  lpSum(err[t] for t in monthly_data.index) # Constraint: Weights sum to 1 
    index += lpSum(wei[i] for i in tickers) == 1
    # Constraint: Absolute value of change in weights from base weigths
    for i in tickers:
        index += aux[i] >= base_weights[i]  - wei[i]
        index += aux[i] >= wei[i] - base_weights[i]
    index += lpSum(aux[i] for i in tickers) <= 1 
    # Constraint: Error term
    for t in monthly_data.index:
        index += lpSum(wei[i]*(monthly_data.loc[t,i]-ff3_monthly.loc[t,'RF']) for i in tickers) - err[t] <= (mkt_opt*ff3_monthly.loc[t,'Mkt-RF']+smb_opt*ff3_monthly.loc[t,'SMB']+hml_opt*ff3_monthly.loc[t,'HML'])
        index += lpSum(wei[i]*(monthly_data.loc[t,i]-ff3_monthly.loc[t,'RF']) for i in tickers) + err[t] >= (mkt_opt*ff3_monthly.loc[t,'Mkt-RF']+smb_opt*ff3_monthly.loc[t,'SMB']+hml_opt*ff3_monthly.loc[t,'HML'])
    # Shares
    for i in tickers:
        index += shares[i] == (aux[i]*B/s_price[i])
    # Transaction Costs
    for i in tickers:
        index += lpSum(aux[i] *B*t_cost[i]/s_price[i]) == tr_cost[i]
    index += lpSum(tr_cost[i] for i in tickers) <= 2000
    # Limit # of stocks in Optimal Portfolio
    for i in tickers: # Forces weight of stock i to be less than binary value of stock i. If stock is not selected binary variable is 0 which then forces weight of stock i to be in the optimal portfolio to be 0.
        index += wei[i] <= binary[i]
    index += lpSum(binary[i] for i in tickers) <= q
    index.solve()

# %%
def others():
    global sharess
    #Change in number of shares
    sharess = pd.DataFrame([v.varValue for v in index.variables() if str(v.name)[0] == 's'], index = [str(v.name) for v in index.variables() if str(v.name)[0] == 's'] , columns = ['Optimal'])
    sharess
    global tr_cost
    #Transaction Costs
    tr_cost = pd.DataFrame([v.varValue for v in index.variables() if str(v.name)[0] == 'T'], index = [str(v.name) for v in index.variables() if str(v.name)[0] == 'T'] , columns = ['Optimal'])
    tr_cost.sum()
    global weii
    #Optimal weights
    weii = pd.DataFrame([v.varValue for v in index.variables() if str(v.name)[0] == 'W'], index = [str(v.name) for v in index.variables() if str(v.name)[0] == 'W'] , columns = ['Optimal'])
    weii.sum()
    global auxx
    #Change of weights
    auxx = pd.DataFrame([v.varValue for v in index.variables() if str(v.name)[0] == 'Y'], index = [str(v.name) for v in index.variables() if str(v.name)[0] == 'Y'] , columns = ['Optimal'])
    auxx.sum()
    global errr
    #Error terms
    errr = pd.DataFrame([v.varValue for v in index.variables() if str(v.name)[0] == 'E'], index = [str(v.name) for v in index.variables() if str(v.name)[0] == 'E'] , columns = ['Optimal'])
    errr.sum()
    global binary_v
    # Check if Binary Values Constraint works
    binary_v = pd.DataFrame([v.varValue for v in index.variables() if v.varValue != 0 and str(v.name)[0] == 'b'], index = [str(v.name) for v in index.variables() if v.varValue != 0 and str(v.name)[0] == 'b'] , columns = ['Optimal'])
    binary_v.sum()
    global opt_weights 
    # Weights in Optimal Portfolio
    opt_weights = pd.DataFrame([v.varValue for v in index.variables() if v.varValue != 0 and str(v.name)[0] == 'W'], index = [str(v.name) for v in index.variables() if v.varValue != 0 and str(v.name)[0] == 'W'] , columns = ['Optimal'])
    opt_weights.style.format('{:,.2%}'.format)
    global weights_new
    weights_new = pd.DataFrame([v.varValue for v in index.variables() if str(v.name[0]) == 'W'], index = [str(v.name).split('_')[1] for v in index.variables() if str(v.name[0]) == 'W'] , columns = ['New Weights'])
    global weights
    weights = pd.DataFrame(np.zeros((len(monthly_data.columns[:-1]),3)), index=monthly_data.columns[:-1], columns=['PORTFOLIO Weights','Difference','New Weights'])
    for t in monthly_data.columns[:-1]:
        weights.loc[t][0] = base_w.loc[t]
        weights.loc[t][1] = weights_new.loc[t][0]-base_w.loc[t][0]
        weights.loc[t][2] = weights_new.loc[t]
    weights
    columns_to_remove = ['PORTFOLIO Weights', 'Difference']
    # Specify the column to filter non-zero values
    column_to_filter = 'New Weights'
    # Create a new DataFrame with selected columns and rows where New Weights is not equal to 0
    global opt_portf_weights
    opt_portf_weights = weights.drop(columns=columns_to_remove)[weights[column_to_filter] != 0]

# %%
def portfolio_betas():
    # CHECK PORTFOLIO BETAS
   
    global port_betas
    port_returns = pd.DataFrame(np.zeros((len(monthly_data.index),2)), index=monthly_data.index, columns=["SP_500","Optimization"])
    for j in port_returns.index:
        port_returns.loc[j]["SP_500"] = monthly_data.loc[j]['SP_500']
        port_returns.loc[j]['Optimization'] = monthly_data.loc[j,:monthly_data.columns[-2]].dot(weights['New Weights'])
    port_returns = port_returns.merge(ff3_monthly[['Mkt-RF','SMB','HML']], left_index=True, right_index=True)
    # Create an empty DataFrame to store the Portfolio Beta
    port_betas = pd.DataFrame(np.zeros((3,4)), index=ff3_monthly.columns[0:3], columns=["SP_500", "Target", "Optimization", "Abs. Diff"])
    port_betas["Target"] = [mkt_opt, smb_opt, hml_opt]# Set the independent variables (Fama French 3 Factors)
    X = port_returns[['Mkt-RF','SMB','HML']]
    # Set the dependent variable (Return of Portfolio)
    Y = port_returns['SP_500']# Fit the multiple linear regression model
    regr = LinearRegression()
    regr.fit(X,Y)
    port_betas['SP_500'] = regr.coef_
    # Set the dependent variable (Return of Portfolio)
    Y = port_returns['Optimization']
    # Fit the multiple linear regression model
    regr = LinearRegression()
    regr.fit(X,Y)
    port_betas['Optimization'] = regr.coef_
    # Abs Difference between Target Betas & Optimal Portfolio Betas
    port_betas["Abs. Diff"] = round(abs(port_betas['Optimization'] - port_betas["Target"]),4)
    port_betas
    return port_betas

# %%
def simulator(beta1,beta2,beta3,begin,final,budget,number):
    global start
    global end
    start=begin
    end=final
    get_spy(beta1,beta2,beta3,start,end)
    #Adjusting tickers list as some tickers will not be included in the monthly_data if there is no data for test date range
    global tickers
    tickers = list(monthly_data.columns[:-1])
    tick_index = tickers + ['SP_500']
    

    # TARGET FACTOR BETAS 
    global base_weights
    global mkt_opt
    global smb_opt
    global hml_opt
    global B
    global q
    
    mkt_opt = beta1                          # TARGET MKT BETA - EXPOSURE OF THE NEW PORTFOLIO TO MARKET FACTOR 
    smb_opt = beta2                           # TARGET SMB BETA - EXPOSURE OF THE NEW PORTFOLIO TO SIZE FACTOR 
    hml_opt = beta3                           # TARGET HML BETA - EXPOSURE OF THE NEW PORTFOLIO TO VALUE FACTOR 
    B = budget                             # BUDGET
    q = number                                # NUMBER OF STOCKS IN THE NEW PORTFOLIO
    base_weights = base_w.T*0               # ONLY HAVE THIS LINE OF CODE WHEN YOU ARE CONSTRUCTING THE PORTFOLIO FROM SCRATCH 
    
    famafrenchreturns()
    to__cal_stock_betas()
    to_cal_stock_price()
    Transaction_Costs()
    optimization()
    others()
    portfolio_betas()
    opt_portf_weights
    global port_betas
    opt_portf_weights

# %%
def out_of_sample():
    global oos1_daily_data
    global oos1_new_performance
    o1_start_d = os_start
    o1_end_d   = os_end
    oos1_daily_data = yf.download(opt_portf_weights.index.tolist(),start=o1_start_d,end=o1_end_d,interval='1mo')
    oos1_daily_data = oos1_daily_data['Adj Close'].pct_change().dropna()
    oos1_daily_data = oos1_daily_data.tz_localize(None)
    oos1_spy_d = pd.DataFrame(yf.download('^GSPC',start=o1_start_d,end=o1_end_d,interval='1mo')['Adj Close'].pct_change())
    oos1_spy_d = oos1_spy_d.drop(oos1_spy_d.index[0]).tz_localize(None)
    oos1_daily_data['SP_500'] = oos1_spy_d['Adj Close']
    oos1_daily_data['Optimized Portfolio'] = ''
    for i in range(len(oos1_daily_data.index)):
        oos1_daily_data.iloc[i,-1] = oos1_daily_data.iloc[i,:-2].dot(opt_portf_weights['New Weights'])
    oos1_daily_data
    init = 1        #Initial Common Value (Can be thought of Initial Investment of $1 USD in each stock)
    oos1_new_returns = pd.DataFrame(np.ones((len(oos1_daily_data),len(oos1_daily_data.columns))), index = oos1_daily_data.index, columns = oos1_daily_data.columns)
    for j in range(1,len(oos1_daily_data.index)):
        oos1_new_returns.iloc[j] = oos1_new_returns.iloc[j-1]*(oos1_daily_data.iloc[j-1][oos1_daily_data.columns])
    oos1_new_performance = pd.DataFrame(np.ones((len(oos1_daily_data),2)), index = oos1_daily_data.index, columns = oos1_daily_data.columns[-2:])
    for j in range(1,len(oos1_daily_data.index)):
        oos1_new_performance.iloc[j] = oos1_new_performance.iloc[j-1]*(oos1_daily_data.iloc[j-1][oos1_daily_data.columns[-2:]]+1)
    
    return oos1_new_performance

# %%
o1_start_d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 o1_start_d
#
# NameError: name 'o1_start_d' is not defined

# %%
def run_with_backtest(nyears):
    
    global n_years
    n_years=nyears
    current_date()
    simulator(1,0,0,n_year_before,n_year_after,1000000,50) 
    out_of_sample()
  
    return oos1_new_performance

# %%
run_with_backtest(3)
# Out:
# [*********************100%%**********************]  501 of 501 completed
#
# 6 Failed downloads:
# ['GEV', 'SOLV', 'SW', 'VLTO']: Exception("%ticker%: Data doesn't exist for startDate = 1593576000, endDate = 1688184000")
# ['BF.B']: Exception('%ticker%: No price data found, symbol may be delisted (1mo 2020-07-01 -> 2023-07-01)')
# ['BRK.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  490 of 490 completed
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l4/hkz5jfdx3t581gbl8x7mfqs40000gn/T/ec571974d6f548159b38bc2b8b6889e4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/l4/hkz5jfdx3t581gbl8x7mfqs40000gn/T/ec571974d6f548159b38bc2b8b6889e4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 2529 COLUMNS
# At line 44769 RHS
# At line 47294 BOUNDS
# At line 47785 ENDATA
# Problem MODEL has 2524 rows, 2485 columns and 41224 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.06 seconds
# Cgl0004I processed model has 1054 rows, 1505 columns (490 integer (490 of which binary)) and 38284 elements
# Cbc0038I Initial state - 36 integers unsatisfied sum - 1
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 2.18104 iterations 684
# Cbc0038I Solution found of 2.18104
# Cbc0038I Relaxing continuous gives 2.18104
# Cbc0038I Before mini branch and bound, 453 integers at bound fixed and 906 continuous
# Cbc0038I Full problem 1054 rows 1505 columns, reduced to 110 rows 109 columns
# Cbc0038I Mini branch and bound improved solution from 2.18104 to 0 (0.18 seconds)
# Cbc0038I After 0.19 seconds - Feasibility pump exiting with objective of 0 - took 0.07 seconds
# Cbc0012I Integer solution of 0 found by feasibility pump after 0 iterations and 0 nodes (0.32 seconds)
# Cbc0001I Search completed - best objective 0, took 0 iterations and 0 nodes (0.33 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.72
# Time (Wallclock seconds):       0.79
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.73   (Wallclock seconds):       0.81
# [*********************100%%**********************]  36 of 36 completed
# [*********************100%%**********************]  1 of 1 completed
# Ticker        SP_500  Optimized Portfolio
# Date
# 2023-08-01  1.000000             1.000000
# 2023-09-01  0.982284             0.983371
# 2023-10-01  0.934427             0.939009
# 2023-11-01  0.913889             0.906084
# 2023-12-01  0.995389             0.993394
# 2024-01-01  1.039414             1.047563
# 2024-02-01  1.055936             1.053306
# 2024-03-01  1.110550             1.061896
# 2024-04-01  1.144998             1.088326
# 2024-05-01  1.097349             1.016469
# 2024-06-01  1.150045             1.048386
# 2024-07-01  1.189917             1.085643

# %%
def current_date():
    global today
    global os_start
    global os_end
    global n_year_before
    global n_year_after
    from datetime import datetime, timedelta
    today = datetime.today()
    one_year_before = today - timedelta(days=365)
    os_start = today - timedelta(days=365)
    two_months_before = os_start - timedelta(days=2*30)
    os_start = two_months_before.replace(day=1)
    one_month_before = today - timedelta(days=30)
    os_end = one_month_before.replace(day=1)
    
    n_year_before = os_start - timedelta(days=(365*n_years))
    n_year_after=n_year_before+timedelta(days=(365*n_years))                           
    os_start=os_start.strftime("%Y-%m-%d")
    os_end=os_end.strftime("%Y-%m-%d")
    n_year_before=n_year_before.strftime("%Y-%m-%d")
    n_year_after=n_year_after.strftime("%Y-%m-%d")
    from datetime import date

    today = date.today()
    formatted_date = today.strftime("%Y-%m-%d")
    today = formatted_date

# %%
def mod_out_of_sample():
    global oos1_daily_data
    global oos1_new_performance
    o1_start_d = os_start
    o1_end_d   = os_end
    oos1_daily_data = yf.download(opt_portf_weights.index.tolist(),start=o1_start_d,end=o1_end_d,interval='1mo')
    oos1_daily_data = oos1_daily_data['Adj Close'].pct_change().dropna()
    oos1_daily_data = oos1_daily_data.tz_localize(None)
    oos1_spy_d = pd.DataFrame(yf.download('^GSPC',start=o1_start_d,end=o1_end_d,interval='1mo')['Adj Close'].pct_change())
    oos1_spy_d = oos1_spy_d.drop(oos1_spy_d.index[0]).tz_localize(None)
    oos1_daily_data['SP_500'] = oos1_spy_d['Adj Close']
    oos1_daily_data['Optimized Portfolio'] = ''
    for i in range(len(oos1_daily_data.index)):
        oos1_daily_data.iloc[i,-1] = oos1_daily_data.iloc[i,:-2].dot(opt_portf_weights['New Weights'])
    oos1_daily_data
    oos1_new_returns = pd.DataFrame(np.ones((len(oos1_daily_data),len(oos1_daily_data.columns))), index = oos1_daily_data.index, columns = oos1_daily_data.columns)
    for j in range(1,len(oos1_daily_data.index)):
        oos1_new_returns.iloc[j] = oos1_new_returns.iloc[j-1]*(oos1_daily_data.iloc[j-1][oos1_daily_data.columns])
    oos1_new_performance = pd.DataFrame(np.ones((len(oos1_daily_data),2)), index = oos1_daily_data.index, columns = oos1_daily_data.columns[-2:])
    for j in range(1,len(oos1_daily_data.index)):
        oos1_new_performance.iloc[j] = oos1_new_performance.iloc[j-1]*(oos1_daily_data.iloc[j-1][oos1_daily_data.columns[-2:]]+1)
    
    return oos1_new_performance

# %%
def mod_out_of_sample1():
    global oos1_daily_data
    global oos1_new_performance
    global o1_start_d
    global o1_end_d
    o1_start_d = out_of_sample_year_start[1]
    o1_end_d   = out_of_sample_year_end[2]
    oos1_daily_data = yf.download(opt_portf_weights.index.tolist(),start=o1_start_d,end=o1_end_d,interval='1mo')
    oos1_daily_data = oos1_daily_data['Adj Close'].pct_change().dropna()
    oos1_daily_data = oos1_daily_data.tz_localize(None)
    oos1_spy_d = pd.DataFrame(yf.download('^GSPC',start=o1_start_d,end=o1_end_d,interval='1mo')['Adj Close'].pct_change())
    oos1_spy_d = oos1_spy_d.drop(oos1_spy_d.index[0]).tz_localize(None)
    oos1_daily_data['SP_500'] = oos1_spy_d['Adj Close']
    oos1_daily_data['Optimized Portfolio'] = ''
    for i in range(len(oos1_daily_data.index)):
        oos1_daily_data.iloc[i,-1] = oos1_daily_data.iloc[i,:-2].dot(opt_portf_weights['New Weights'])
    oos1_daily_data
    oos1_new_returns = pd.DataFrame(np.ones((len(oos1_daily_data),len(oos1_daily_data.columns))), index = oos1_daily_data.index, columns = oos1_daily_data.columns)
    for j in range(1,len(oos1_daily_data.index)):
        oos1_new_returns.iloc[j] = oos1_new_returns.iloc[j-1]*(oos1_daily_data.iloc[j-1][oos1_daily_data.columns])
    oos1_new_performance = pd.DataFrame(np.ones((len(oos1_daily_data),2)), index = oos1_daily_data.index, columns = oos1_daily_data.columns[-2:])
    for j in range(1,len(oos1_daily_data.index)):
        oos1_new_performance.iloc[j] = oos1_new_performance.iloc[j-1]*(oos1_daily_data.iloc[j-1][oos1_daily_data.columns[-2:]]+1)
    
    return oos1_new_performance

# %%
os_start
# Out:
# '2023-07-01'
# 8I Full problem 1050 rows 1453 columns, reduced to 268 rows 295 columns
# Cbc0010I After 26000 nodes, 1911 on tree, 0.0084597565 best solution, best possible 0 (925.68 seconds)
# Cbc0010I After 27000 nodes, 1940 on tree, 0.0084597565 best solution, best possible 0 (7762.77 seconds)
# Cbc0010I After 28000 nodes, 2037 on tree, 0.0084597565 best solution, best possible 0 (11855.43 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 253 rows 273 columns
# Cbc0010I After 29000 nodes, 2094 on tree, 0.0084597565 best solution, best possible 0 (17471.22 seconds)
# Cbc0010I After 30000 nodes, 2076 on tree, 0.0084597565 best solution, best possible 0 (22841.27 seconds)
# Cbc0010I After 31000 nodes, 2152 on tree, 0.0084597565 best solution, best possible 0 (25756.13 seconds)
# Cbc0010I After 32000 nodes, 2344 on tree, 0.0084597565 best solution, best possible 0 (27900.99 seconds)
# Cbc0010I After 33000 nodes, 2375 on tree, 0.0084597565 best solution, best possible 0 (29167.73 seconds)
# Cbc0010I After 34000 nodes, 2382 on tree, 0.0084597565 best solution, best possible 0 (30522.60 seconds)
# Cbc0010I After 35000 nodes, 2382 on tree, 0.0084597565 best solution, best possible 0 (31460.49 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 253 rows 272 columns
# Cbc0010I After 36000 nodes, 2373 on tree, 0.0084597565 best solution, best possible 0 (34746.76 seconds)
# Cbc0010I After 37000 nodes, 2699 on tree, 0.0084597565 best solution, best possible 0 (37493.46 seconds)
# Cbc0010I After 38000 nodes, 2712 on tree, 0.0084597565 best solution, best possible 0 (37557.05 seconds)
# Cbc0010I After 39000 nodes, 2897 on tree, 0.0084597565 best solution, best possible 0 (41152.13 seconds)
# Cbc0010I After 40000 nodes, 2968 on tree, 0.0084597565 best solution, best possible 0 (43107.03 seconds)
# Cbc0010I After 41000 nodes, 3001 on tree, 0.0084597565 best solution, best possible 0 (45710.15 seconds)
# Cbc0010I After 42000 nodes, 2960 on tree, 0.0084597565 best solution, best possible 0 (46723.80 seconds)
# Cbc0010I After 43000 nodes, 2972 on tree, 0.0084597565 best solution, best possible 0 (48463.97 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 256 rows 277 columns
# Cbc0010I After 44000 nodes, 3081 on tree, 0.0084597565 best solution, best possible 0 (51305.05 seconds)
# Cbc0010I After 45000 nodes, 3174 on tree, 0.0084597565 best solution, best possible 0 (53246.85 seconds)
# Cbc0010I After 46000 nodes, 3194 on tree, 0.0084597565 best solution, best possible 0 (57774.39 seconds)
# Cbc0010I After 47000 nodes, 3202 on tree, 0.0084597565 best solution, best possible 0 (58761.35 seconds)
# Cbc0010I After 48000 nodes, 3290 on tree, 0.0084597565 best solution, best possible 0 (61148.83 seconds)
# Cbc0010I After 49000 nodes, 3330 on tree, 0.0084597565 best solution, best possible 0 (63134.75 seconds)
# Cbc0010I After 50000 nodes, 3328 on tree, 0.0084597565 best solution, best possible 0 (64279.58 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 257 rows 278 columns
# Cbc0010I After 51000 nodes, 3322 on tree, 0.0084597565 best solution, best possible 0 (66329.62 seconds)
# Cbc0010I After 52000 nodes, 3320 on tree, 0.0084597565 best solution, best possible 0 (66369.40 seconds)
# Cbc0010I After 53000 nodes, 3285 on tree, 0.0084597565 best solution, best possible 0 (66410.23 seconds)
# Cbc0010I After 54000 nodes, 3272 on tree, 0.0084597565 best solution, best possible 0 (66437.83 seconds)
# Cbc0010I After 55000 nodes, 3271 on tree, 0.0084597565 best solution, best possible 0 (66478.68 seconds)
# Cbc0010I After 56000 nodes, 3288 on tree, 0.0084597565 best solution, best possible 0 (66518.24 seconds)
# Cbc0010I After 57000 nodes, 3313 on tree, 0.0084597565 best solution, best possible 0 (66554.79 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 265 rows 291 columns
# Cbc0010I After 58000 nodes, 3338 on tree, 0.0084597565 best solution, best possible 0 (66588.22 seconds)
# Cbc0010I After 59000 nodes, 3516 on tree, 0.0084597565 best solution, best possible 0 (66626.69 seconds)
# Cbc0010I After 60000 nodes, 3781 on tree, 0.0084597565 best solution, best possible 0 (66660.71 seconds)
# Cbc0010I After 61000 nodes, 3951 on tree, 0.0084597565 best solution, best possible 0 (66696.91 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 263 rows 287 columns
# Cbc0010I After 62000 nodes, 3952 on tree, 0.0084597565 best solution, best possible 0 (66730.01 seconds)
# Cbc0010I After 63000 nodes, 4233 on tree, 0.0084597565 best solution, best possible 0 (66764.56 seconds)
# Cbc0010I After 64000 nodes, 4345 on tree, 0.0084597565 best solution, best possible 0 (66799.48 seconds)
# Cbc0010I After 65000 nodes, 4461 on tree, 0.0084597565 best solution, best possible 0 (66832.88 seconds)
# Cbc0010I After 66000 nodes, 4453 on tree, 0.0084597565 best solution, best possible 0 (66862.99 seconds)
# Cbc0010I After 67000 nodes, 4688 on tree, 0.0084597565 best solution, best possible 0 (66898.13 seconds)
# Cbc0010I After 68000 nodes, 4846 on tree, 0.0084597565 best solution, best possible 0 (66931.54 seconds)
# Cbc0010I After 69000 nodes, 5013 on tree, 0.0084597565 best solution, best possible 0 (66965.26 seconds)
# Cbc0010I After 70000 nodes, 4981 on tree, 0.0084597565 best solution, best possible 0 (66996.41 seconds)
# Cbc0010I After 71000 nodes, 5042 on tree, 0.0084597565 best solution, best possible 0 (67035.40 seconds)
# Cbc0010I After 72000 nodes, 5090 on tree, 0.0084597565 best solution, best possible 0 (67072.86 seconds)
# Cbc0010I After 73000 nodes, 5163 on tree, 0.0084597565 best solution, best possible 0 (67116.79 seconds)
# Cbc0010I After 74000 nodes, 5165 on tree, 0.0084597565 best solution, best possible 0 (67150.85 seconds)
# Cbc0010I After 75000 nodes, 5194 on tree, 0.0084597565 best solution, best possible 0 (67193.46 seconds)
# Cbc0010I After 76000 nodes, 5273 on tree, 0.0084597565 best solution, best possible 0 (67231.84 seconds)
# Cbc0010I After 77000 nodes, 5320 on tree, 0.0084597565 best solution, best possible 0 (67271.25 seconds)
# Cbc0010I After 78000 nodes, 5310 on tree, 0.0084597565 best solution, best possible 0 (67303.22 seconds)
# Cbc0010I After 79000 nodes, 5371 on tree, 0.0084597565 best solution, best possible 0 (67342.29 seconds)
# Cbc0010I After 80000 nodes, 5359 on tree, 0.0084597565 best solution, best possible 0 (67385.76 seconds)
# Cbc0010I After 81000 nodes, 5404 on tree, 0.0084597565 best solution, best possible 0 (67423.09 seconds)
# Cbc0010I After 82000 nodes, 5487 on tree, 0.0084597565 best solution, best possible 0 (67452.57 seconds)
# Cbc0010I After 83000 nodes, 5491 on tree, 0.0084597565 best solution, best possible 0 (67490.55 seconds)
# Cbc0010I After 84000 nodes, 5524 on tree, 0.0084597565 best solution, best possible 0 (67530.57 seconds)
# Cbc0010I After 85000 nodes, 5543 on tree, 0.0084597565 best solution, best possible 0 (67568.85 seconds)
# Cbc0010I After 86000 nodes, 5468 on tree, 0.0084597565 best solution, best possible 0 (67601.67 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 257 rows 279 columns
# Cbc0010I After 87000 nodes, 5548 on tree, 0.0084597565 best solution, best possible 0 (67638.39 seconds)
# Cbc0010I After 88000 nodes, 5705 on tree, 0.0084597565 best solution, best possible 0 (67674.25 seconds)
# Cbc0010I After 89000 nodes, 5821 on tree, 0.0084597565 best solution, best possible 0 (67708.43 seconds)
# Cbc0010I After 90000 nodes, 5828 on tree, 0.0084597565 best solution, best possible 0 (67741.26 seconds)
# Cbc0010I After 91000 nodes, 5893 on tree, 0.0084597565 best solution, best possible 0 (67777.79 seconds)
# Cbc0010I After 92000 nodes, 5949 on tree, 0.0084597565 best solution, best possible 0 (67815.53 seconds)
# Cbc0010I After 93000 nodes, 5984 on tree, 0.0084597565 best solution, best possible 0 (67853.73 seconds)
# Cbc0010I After 94000 nodes, 6008 on tree, 0.0084597565 best solution, best possible 0 (67887.75 seconds)
# Cbc0010I After 95000 nodes, 6020 on tree, 0.0084597565 best solution, best possible 0 (67925.70 seconds)
# Cbc0010I After 96000 nodes, 6021 on tree, 0.0084597565 best solution, best possible 0 (67964.42 seconds)
# Cbc0010I After 97000 nodes, 6045 on tree, 0.0084597565 best solution, best possible 0 (68004.72 seconds)
# Cbc0010I After 98000 nodes, 6014 on tree, 0.0084597565 best solution, best possible 0 (68038.16 seconds)
# Cbc0010I After 99000 nodes, 6088 on tree, 0.0084597565 best solution, best possible 0 (68075.78 seconds)
# Cbc0010I After 100000 nodes, 6165 on tree, 0.0084597565 best solution, best possible 0 (68121.47 seconds)
# Cbc0010I After 101000 nodes, 6197 on tree, 0.0084597565 best solution, best possible 0 (68164.90 seconds)
# Cbc0010I After 102000 nodes, 6225 on tree, 0.0084597565 best solution, best possible 0 (68211.76 seconds)
# Cbc0010I After 103000 nodes, 6259 on tree, 0.0084597565 best solution, best possible 0 (68256.18 seconds)
# Cbc0010I After 104000 nodes, 6241 on tree, 0.0084597565 best solution, best possible 0 (68298.54 seconds)
# Cbc0010I After 105000 nodes, 6261 on tree, 0.0084597565 best solution, best possible 0 (68341.58 seconds)
# Cbc0010I After 106000 nodes, 6343 on tree, 0.0084597565 best solution, best possible 0 (68384.75 seconds)
# Cbc0010I After 107000 nodes, 6414 on tree, 0.0084597565 best solution, best possible 0 (68426.73 seconds)
# Cbc0010I After 108000 nodes, 6423 on tree, 0.0084597565 best solution, best possible 0 (68468.39 seconds)
# Cbc0010I After 109000 nodes, 6482 on tree, 0.0084597565 best solution, best possible 0 (68508.74 seconds)
# Cbc0010I After 110000 nodes, 6476 on tree, 0.0084597565 best solution, best possible 0 (68550.64 seconds)
# Cbc0010I After 111000 nodes, 6513 on tree, 0.0084597565 best solution, best possible 0 (68597.57 seconds)
# Cbc0010I After 112000 nodes, 6533 on tree, 0.0084597565 best solution, best possible 0 (68641.34 seconds)
# Cbc0010I After 113000 nodes, 6539 on tree, 0.0084597565 best solution, best possible 0 (68684.75 seconds)
# Cbc0010I After 114000 nodes, 6585 on tree, 0.0084597565 best solution, best possible 0 (68729.14 seconds)
# Cbc0010I After 115000 nodes, 6643 on tree, 0.0084597565 best solution, best possible 0 (68772.52 seconds)
# Cbc0010I After 116000 nodes, 6683 on tree, 0.0084597565 best solution, best possible 0 (68817.27 seconds)
# Cbc0010I After 117000 nodes, 6728 on tree, 0.0084597565 best solution, best possible 0 (68857.46 seconds)
# Cbc0010I After 118000 nodes, 6784 on tree, 0.0084597565 best solution, best possible 0 (68895.94 seconds)
# Cbc0010I After 119000 nodes, 6790 on tree, 0.0084597565 best solution, best possible 0 (68939.38 seconds)
# Cbc0010I After 120000 nodes, 6752 on tree, 0.0084597565 best solution, best possible 0 (68983.01 seconds)
# Cbc0010I After 121000 nodes, 6783 on tree, 0.0084597565 best solution, best possible 0 (69028.67 seconds)
# Cbc0010I After 122000 nodes, 6864 on tree, 0.0084597565 best solution, best possible 0 (69070.28 seconds)
# Cbc0010I After 123000 nodes, 6899 on tree, 0.0084597565 best solution, best possible 0 (69111.54 seconds)
# Cbc0010I After 124000 nodes, 6888 on tree, 0.0084597565 best solution, best possible 0 (69154.24 seconds)
# Cbc0010I After 125000 nodes, 6916 on tree, 0.0084597565 best solution, best possible 0 (75429.30 seconds)
# Cbc0010I After 126000 nodes, 6982 on tree, 0.0084597565 best solution, best possible 0 (75477.67 seconds)
# Cbc0010I After 127000 nodes, 6978 on tree, 0.0084597565 best solution, best possible 0 (75528.23 seconds)
# Cbc0010I After 128000 nodes, 7028 on tree, 0.0084597565 best solution, best possible 0 (75575.62 seconds)
# Cbc0010I After 129000 nodes, 7033 on tree, 0.0084597565 best solution, best possible 0 (75617.68 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 262 rows 286 columns
# Cbc0010I After 130000 nodes, 6992 on tree, 0.0084597565 best solution, best possible 0 (75664.80 seconds)
# Cbc0010I After 131000 nodes, 7075 on tree, 0.0084597565 best solution, best possible 0 (75714.55 seconds)
# Cbc0010I After 132000 nodes, 7092 on tree, 0.0084597565 best solution, best possible 0 (75764.64 seconds)
# Cbc0010I After 133000 nodes, 7099 on tree, 0.0084597565 best solution, best possible 0 (75809.98 seconds)
# Cbc0010I After 134000 nodes, 7072 on tree, 0.0084597565 best solution, best possible 0 (75860.07 seconds)
# Cbc0010I After 135000 nodes, 7104 on tree, 0.0084597565 best solution, best possible 0 (75907.60 seconds)
# Cbc0010I After 136000 nodes, 7150 on tree, 0.0084597565 best solution, best possible 0 (75958.58 seconds)
# Cbc0010I After 137000 nodes, 7126 on tree, 0.0084597565 best solution, best possible 0 (76007.28 seconds)
# Cbc0010I After 138000 nodes, 7138 on tree, 0.0084597565 best solution, best possible 0 (76047.77 seconds)
# Cbc0010I After 139000 nodes, 7187 on tree, 0.0084597565 best solution, best possible 0 (76082.75 seconds)
# Cbc0010I After 140000 nodes, 7147 on tree, 0.0084597565 best solution, best possible 0 (76121.35 seconds)
# Cbc0010I After 141000 nodes, 7154 on tree, 0.0084597565 best solution, best possible 0 (76160.99 seconds)
# Cbc0010I After 142000 nodes, 7135 on tree, 0.0084597565 best solution, best possible 0 (76203.20 seconds)
# Cbc0010I After 143000 nodes, 7137 on tree, 0.0084597565 best solution, best possible 0 (76242.34 seconds)
# Cbc0010I After 144000 nodes, 7101 on tree, 0.0084597565 best solution, best possible 0 (76282.61 seconds)
# Cbc0010I After 145000 nodes, 7062 on tree, 0.0084597565 best solution, best possible 0 (76323.67 seconds)
# Cbc0010I After 146000 nodes, 7021 on tree, 0.0084597565 best solution, best possible 0 (76363.42 seconds)
# Cbc0010I After 147000 nodes, 6957 on tree, 0.0084597565 best solution, best possible 0 (76404.83 seconds)
# Cbc0010I After 148000 nodes, 6900 on tree, 0.0084597565 best solution, best possible 0 (76445.40 seconds)
# Cbc0010I After 149000 nodes, 6949 on tree, 0.0084597565 best solution, best possible 0 (76487.90 seconds)
# Cbc0010I After 150000 nodes, 7050 on tree, 0.0084597565 best solution, best possible 0 (76529.40 seconds)
# Cbc0010I After 151000 nodes, 7365 on tree, 0.0084597565 best solution, best possible 0 (76567.92 seconds)
# Cbc0010I After 152000 nodes, 7522 on tree, 0.0084597565 best solution, best possible 0 (76603.13 seconds)
# Cbc0010I After 153000 nodes, 7638 on tree, 0.0084597565 best solution, best possible 0 (76639.60 seconds)
# Cbc0010I After 154000 nodes, 7717 on tree, 0.0084597565 best solution, best possible 0 (76674.24 seconds)
# Cbc0010I After 155000 nodes, 7797 on tree, 0.0084597565 best solution, best possible 0 (76708.22 seconds)
# Cbc0010I After 156000 nodes, 7854 on tree, 0.0084597565 best solution, best possible 0 (76742.63 seconds)
# Cbc0010I After 157000 nodes, 7924 on tree, 0.0084597565 best solution, best possible 0 (76777.84 seconds)
# Cbc0010I After 158000 nodes, 7922 on tree, 0.0084597565 best solution, best possible 0 (76814.16 seconds)
# Cbc0010I After 159000 nodes, 7985 on tree, 0.0084597565 best solution, best possible 0 (76852.82 seconds)
# Cbc0010I After 160000 nodes, 8164 on tree, 0.0084597565 best solution, best possible 0 (76889.58 seconds)
# Cbc0010I After 161000 nodes, 8365 on tree, 0.0084597565 best solution, best possible 0 (76926.16 seconds)
# Cbc0010I After 162000 nodes, 8471 on tree, 0.0084597565 best solution, best possible 0 (76962.28 seconds)
# Cbc0010I After 163000 nodes, 8607 on tree, 0.0084597565 best solution, best possible 0 (76999.82 seconds)
# Cbc0010I After 164000 nodes, 8910 on tree, 0.0084597565 best solution, best possible 0 (77032.65 seconds)
# Cbc0010I After 165000 nodes, 8964 on tree, 0.0084597565 best solution, best possible 0 (77069.71 seconds)
# Cbc0010I After 166000 nodes, 9196 on tree, 0.0084597565 best solution, best possible 0 (77104.51 seconds)
# Cbc0010I After 167000 nodes, 9436 on tree, 0.0084597565 best solution, best possible 0 (77137.92 seconds)
# Cbc0010I After 168000 nodes, 9524 on tree, 0.0084597565 best solution, best possible 0 (77176.10 seconds)
# Cbc0010I After 169000 nodes, 9708 on tree, 0.0084597565 best solution, best possible 0 (77212.51 seconds)
# Cbc0010I After 170000 nodes, 9917 on tree, 0.0084597565 best solution, best possible 0 (77253.10 seconds)
# Cbc0010I After 171000 nodes, 10226 on tree, 0.0084597565 best solution, best possible 0 (77288.80 seconds)
# Cbc0010I After 172000 nodes, 10443 on tree, 0.0084597565 best solution, best possible 0 (77325.67 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 268 rows 294 columns
# Cbc0010I After 173000 nodes, 10451 on tree, 0.0084597565 best solution, best possible 0 (77354.71 seconds)
# Cbc0010I After 174000 nodes, 10658 on tree, 0.0084597565 best solution, best possible 0 (77392.04 seconds)
# Cbc0010I After 175000 nodes, 10809 on tree, 0.0084597565 best solution, best possible 0 (77429.38 seconds)
# Cbc0010I After 176000 nodes, 11118 on tree, 0.0084597565 best solution, best possible 0 (77466.59 seconds)
# Cbc0010I After 177000 nodes, 11081 on tree, 0.0084597565 best solution, best possible 0 (77504.75 seconds)
# Cbc0010I After 178000 nodes, 11327 on tree, 0.0084597565 best solution, best possible 0 (77541.86 seconds)
# Cbc0010I After 179000 nodes, 11679 on tree, 0.0084597565 best solution, best possible 0 (77577.53 seconds)
# Cbc0010I After 180000 nodes, 11978 on tree, 0.0084597565 best solution, best possible 0 (77612.26 seconds)
# Cbc0010I After 181000 nodes, 11999 on tree, 0.0084597565 best solution, best possible 0 (77653.54 seconds)
# Cbc0010I After 182000 nodes, 12213 on tree, 0.0084597565 best solution, best possible 0 (77689.37 seconds)
# Cbc0010I After 183000 nodes, 12269 on tree, 0.0084597565 best solution, best possible 0 (77730.02 seconds)
# Cbc0010I After 184000 nodes, 12429 on tree, 0.0084597565 best solution, best possible 0 (77768.56 seconds)
# Cbc0010I After 185000 nodes, 12430 on tree, 0.0084597565 best solution, best possible 0 (77811.11 seconds)
# Cbc0010I After 186000 nodes, 12561 on tree, 0.0084597565 best solution, best possible 0 (77850.52 seconds)
# Cbc0010I After 187000 nodes, 12637 on tree, 0.0084597565 best solution, best possible 0 (77893.98 seconds)
# Cbc0010I After 188000 nodes, 12701 on tree, 0.0084597565 best solution, best possible 0 (77936.21 seconds)
# Cbc0010I After 189000 nodes, 12760 on tree, 0.0084597565 best solution, best possible 0 (77986.95 seconds)
# Cbc0010I After 190000 nodes, 12807 on tree, 0.0084597565 best solution, best possible 0 (78034.57 seconds)
# Cbc0010I After 191000 nodes, 12931 on tree, 0.0084597565 best solution, best possible 0 (78075.50 seconds)
# Cbc0010I After 192000 nodes, 13029 on tree, 0.0084597565 best solution, best possible 0 (78118.24 seconds)
# Cbc0010I After 193000 nodes, 13060 on tree, 0.0084597565 best solution, best possible 0 (78163.91 seconds)
# Cbc0010I After 194000 nodes, 13288 on tree, 0.0084597565 best solution, best possible 0 (78200.57 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 270 rows 297 columns
# Cbc0010I After 195000 nodes, 13381 on tree, 0.0084597565 best solution, best possible 0 (78238.49 seconds)
# Cbc0010I After 196000 nodes, 13444 on tree, 0.0084597565 best solution, best possible 0 (78277.78 seconds)
# Cbc0010I After 197000 nodes, 13451 on tree, 0.0084597565 best solution, best possible 0 (78320.07 seconds)
# Cbc0010I After 198000 nodes, 13598 on tree, 0.0084597565 best solution, best possible 0 (78357.06 seconds)
# Cbc0010I After 199000 nodes, 13691 on tree, 0.0084597565 best solution, best possible 0 (78398.81 seconds)
# Cbc0010I After 200000 nodes, 13795 on tree, 0.0084597565 best solution, best possible 0 (78439.43 seconds)
# Cbc0010I After 201000 nodes, 13795 on tree, 0.0084597565 best solution, best possible 0 (78491.87 seconds)
# Cbc0010I After 202000 nodes, 13928 on tree, 0.0084597565 best solution, best possible 0 (78539.66 seconds)
# Cbc0010I After 203000 nodes, 14067 on tree, 0.0084597565 best solution, best possible 0 (78582.98 seconds)
# Cbc0010I After 204000 nodes, 14160 on tree, 0.0084597565 best solution, best possible 0 (78628.30 seconds)
# Cbc0010I After 205000 nodes, 14154 on tree, 0.0084597565 best solution, best possible 0 (78677.28 seconds)
# Cbc0010I After 206000 nodes, 14222 on tree, 0.0084597565 best solution, best possible 0 (78722.27 seconds)
# Cbc0010I After 207000 nodes, 14303 on tree, 0.0084597565 best solution, best possible 0 (78763.81 seconds)
# Cbc0010I After 208000 nodes, 14338 on tree, 0.0084597565 best solution, best possible 0 (78807.37 seconds)
# Cbc0010I After 209000 nodes, 14289 on tree, 0.0084597565 best solution, best possible 0 (78856.03 seconds)
# Cbc0010I After 210000 nodes, 14401 on tree, 0.0084597565 best solution, best possible 0 (78899.81 seconds)
# Cbc0010I After 211000 nodes, 14509 on tree, 0.0084597565 best solution, best possible 0 (78938.99 seconds)
# Cbc0010I After 212000 nodes, 14642 on tree, 0.0084597565 best solution, best possible 0 (78980.87 seconds)
# Cbc0010I After 213000 nodes, 14623 on tree, 0.0084597565 best solution, best possible 0 (79028.03 seconds)
# Cbc0010I After 214000 nodes, 14819 on tree, 0.0084597565 best solution, best possible 0 (79068.14 seconds)
# Cbc0010I After 215000 nodes, 14865 on tree, 0.0084597565 best solution, best possible 0 (79114.53 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 252 rows 271 columns
# Cbc0010I After 216000 nodes, 14871 on tree, 0.0084597565 best solution, best possible 0 (79161.43 seconds)
# Cbc0010I After 217000 nodes, 14879 on tree, 0.0084597565 best solution, best possible 0 (79202.93 seconds)
# Cbc0010I After 218000 nodes, 14999 on tree, 0.0084597565 best solution, best possible 0 (79246.26 seconds)
# Cbc0010I After 219000 nodes, 15051 on tree, 0.0084597565 best solution, best possible 0 (79289.84 seconds)
# Cbc0010I After 220000 nodes, 15191 on tree, 0.0084597565 best solution, best possible 0 (79335.08 seconds)
# Cbc0010I After 221000 nodes, 15210 on tree, 0.0084597565 best solution, best possible 0 (79383.45 seconds)
# Cbc0010I After 222000 nodes, 15247 on tree, 0.0084597565 best solution, best possible 0 (79429.00 seconds)
# Cbc0010I After 223000 nodes, 15441 on tree, 0.0084597565 best solution, best possible 0 (79469.31 seconds)
# Cbc0010I After 224000 nodes, 15670 on tree, 0.0084597565 best solution, best possible 0 (79505.32 seconds)
# Cbc0010I After 225000 nodes, 15693 on tree, 0.0084597565 best solution, best possible 0 (79551.56 seconds)
# Cbc0010I After 226000 nodes, 15944 on tree, 0.0084597565 best solution, best possible 0 (79590.55 seconds)
# Cbc0010I After 227000 nodes, 16256 on tree, 0.0084597565 best solution, best possible 0 (79627.97 seconds)
# Cbc0010I After 228000 nodes, 16544 on tree, 0.0084597565 best solution, best possible 0 (79663.50 seconds)
# Cbc0010I After 229000 nodes, 16580 on tree, 0.0084597565 best solution, best possible 0 (79712.17 seconds)
# Cbc0010I After 230000 nodes, 16704 on tree, 0.0084597565 best solution, best possible 0 (79757.23 seconds)
# Cbc0010I After 231000 nodes, 16781 on tree, 0.0084597565 best solution, best possible 0 (79801.51 seconds)
# Cbc0010I After 232000 nodes, 16809 on tree, 0.0084597565 best solution, best possible 0 (79848.77 seconds)
# Cbc0010I After 233000 nodes, 16811 on tree, 0.0084597565 best solution, best possible 0 (79897.35 seconds)
# Cbc0010I After 234000 nodes, 17146 on tree, 0.0084597565 best solution, best possible 0 (79935.26 seconds)
# Cbc0010I After 235000 nodes, 17247 on tree, 0.0084597565 best solution, best possible 0 (79977.31 seconds)
# Cbc0010I After 236000 nodes, 17409 on tree, 0.0084597565 best solution, best possible 0 (80015.22 seconds)
# Cbc0010I After 237000 nodes, 17393 on tree, 0.0084597565 best solution, best possible 0 (80058.88 seconds)
# Cbc0010I After 238000 nodes, 17525 on tree, 0.0084597565 best solution, best possible 0 (80098.67 seconds)
# Cbc0010I After 239000 nodes, 17736 on tree, 0.0084597565 best solution, best possible 0 (80143.52 seconds)
# Cbc0010I After 240000 nodes, 17802 on tree, 0.0084597565 best solution, best possible 0 (80188.06 seconds)
# Cbc0010I After 241000 nodes, 17770 on tree, 0.0084597565 best solution, best possible 0 (80235.36 seconds)
# Cbc0010I After 242000 nodes, 17819 on tree, 0.0084597565 best solution, best possible 0 (80278.57 seconds)
# Cbc0010I After 243000 nodes, 17890 on tree, 0.0084597565 best solution, best possible 0 (80323.28 seconds)
# Cbc0010I After 244000 nodes, 17940 on tree, 0.0084597565 best solution, best possible 0 (80369.71 seconds)
# Cbc0010I After 245000 nodes, 17897 on tree, 0.0084597565 best solution, best possible 0 (80424.64 seconds)
# Cbc0010I After 246000 nodes, 17984 on tree, 0.0084597565 best solution, best possible 0 (80474.86 seconds)
# Cbc0010I After 247000 nodes, 18089 on tree, 0.0084597565 best solution, best possible 0 (80525.80 seconds)
# Cbc0010I After 248000 nodes, 18206 on tree, 0.0084597565 best solution, best possible 0 (80573.89 seconds)
# Cbc0010I After 249000 nodes, 18203 on tree, 0.0084597565 best solution, best possible 0 (80644.51 seconds)
# Cbc0010I After 250000 nodes, 18272 on tree, 0.0084597565 best solution, best possible 0 (80691.92 seconds)
# Cbc0010I After 251000 nodes, 18390 on tree, 0.0084597565 best solution, best possible 0 (80728.96 seconds)
# Cbc0010I After 252000 nodes, 18446 on tree, 0.0084597565 best solution, best possible 0 (84586.52 seconds)
# Cbc0010I After 253000 nodes, 18466 on tree, 0.0084597565 best solution, best possible 0 (86638.15 seconds)
# Cbc0010I After 254000 nodes, 18621 on tree, 0.0084597565 best solution, best possible 0 (88681.01 seconds)
# Cbc0010I After 255000 nodes, 18680 on tree, 0.0084597565 best solution, best possible 0 (91662.63 seconds)
# Cbc0010I After 256000 nodes, 18781 on tree, 0.0084597565 best solution, best possible 0 (95728.18 seconds)
# Cbc0010I After 257000 nodes, 18826 on tree, 0.0084597565 best solution, best possible 0 (103666.41 seconds)
# Cbc0010I After 258000 nodes, 18941 on tree, 0.0084597565 best solution, best possible 0 (105765.74 seconds)
# Cbc0010I After 259000 nodes, 18986 on tree, 0.0084597565 best solution, best possible 0 (109652.49 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 258 rows 279 columns
# Cbc0010I After 260000 nodes, 19022 on tree, 0.0084597565 best solution, best possible 0 (112833.88 seconds)
# Cbc0010I After 261000 nodes, 19018 on tree, 0.0084597565 best solution, best possible 0 (113977.01 seconds)
# Cbc0010I After 262000 nodes, 19037 on tree, 0.0084597565 best solution, best possible 0 (114394.59 seconds)
# Cbc0010I After 263000 nodes, 19288 on tree, 0.0084597565 best solution, best possible 0 (116792.93 seconds)
# Cbc0010I After 264000 nodes, 19403 on tree, 0.0084597565 best solution, best possible 0 (119865.42 seconds)
# Cbc0010I After 265000 nodes, 19402 on tree, 0.0084597565 best solution, best possible 0 (121551.23 seconds)
# Cbc0010I After 266000 nodes, 19457 on tree, 0.0084597565 best solution, best possible 0 (123493.44 seconds)
# Cbc0010I After 267000 nodes, 19500 on tree, 0.0084597565 best solution, best possible 0 (125604.11 seconds)
# Cbc0010I After 268000 nodes, 19558 on tree, 0.0084597565 best solution, best possible 0 (125642.82 seconds)
# Cbc0010I After 269000 nodes, 19583 on tree, 0.0084597565 best solution, best possible 0 (125683.62 seconds)
# Cbc0010I After 270000 nodes, 19683 on tree, 0.0084597565 best solution, best possible 0 (125720.18 seconds)
# Cbc0010I After 271000 nodes, 19778 on tree, 0.0084597565 best solution, best possible 0 (125757.15 seconds)
# Cbc0010I After 272000 nodes, 19953 on tree, 0.0084597565 best solution, best possible 0 (125795.34 seconds)
# Cbc0010I After 273000 nodes, 19970 on tree, 0.0084597565 best solution, best possible 0 (125836.57 seconds)
# Cbc0010I After 274000 nodes, 20190 on tree, 0.0084597565 best solution, best possible 0 (125872.71 seconds)
# Cbc0010I After 275000 nodes, 20429 on tree, 0.0084597565 best solution, best possible 0 (125906.45 seconds)
# Cbc0010I After 276000 nodes, 20548 on tree, 0.0084597565 best solution, best possible 0 (125941.91 seconds)
# Cbc0010I After 277000 nodes, 20611 on tree, 0.0084597565 best solution, best possible 0 (125980.87 seconds)
# Cbc0010I After 278000 nodes, 20772 on tree, 0.0084597565 best solution, best possible 0 (126014.40 seconds)
# Cbc0010I After 279000 nodes, 20869 on tree, 0.0084597565 best solution, best possible 0 (126051.93 seconds)
# Cbc0010I After 280000 nodes, 21093 on tree, 0.0084597565 best solution, best possible 0 (126086.76 seconds)
# Cbc0010I After 281000 nodes, 21081 on tree, 0.0084597565 best solution, best possible 0 (126128.27 seconds)
# Cbc0010I After 282000 nodes, 21200 on tree, 0.0084597565 best solution, best possible 0 (126166.24 seconds)
# Cbc0010I After 283000 nodes, 21256 on tree, 0.0084597565 best solution, best possible 0 (126204.44 seconds)
# Cbc0010I After 284000 nodes, 21296 on tree, 0.0084597565 best solution, best possible 0 (126243.01 seconds)
# Cbc0010I After 285000 nodes, 21324 on tree, 0.0084597565 best solution, best possible 0 (126281.29 seconds)
# Cbc0010I After 286000 nodes, 21450 on tree, 0.0084597565 best solution, best possible 0 (126318.30 seconds)
# Cbc0010I After 287000 nodes, 21534 on tree, 0.0084597565 best solution, best possible 0 (126356.64 seconds)
# Cbc0010I After 288000 nodes, 21602 on tree, 0.0084597565 best solution, best possible 0 (126394.96 seconds)
# Cbc0010I After 289000 nodes, 21611 on tree, 0.0084597565 best solution, best possible 0 (126434.45 seconds)
# Cbc0010I After 290000 nodes, 21651 on tree, 0.0084597565 best solution, best possible 0 (126473.35 seconds)
# Cbc0010I After 291000 nodes, 21726 on tree, 0.0084597565 best solution, best possible 0 (126511.80 seconds)
# Cbc0010I After 292000 nodes, 21810 on tree, 0.0084597565 best solution, best possible 0 (126549.39 seconds)
# Cbc0010I After 293000 nodes, 21874 on tree, 0.0084597565 best solution, best possible 0 (126589.36 seconds)
# Cbc0010I After 294000 nodes, 21999 on tree, 0.0084597565 best solution, best possible 0 (126624.50 seconds)
# Cbc0010I After 295000 nodes, 22125 on tree, 0.0084597565 best solution, best possible 0 (126660.39 seconds)
# Cbc0010I After 296000 nodes, 22210 on tree, 0.0084597565 best solution, best possible 0 (126698.49 seconds)
# Cbc0010I After 297000 nodes, 22207 on tree, 0.0084597565 best solution, best possible 0 (126740.69 seconds)
# Cbc0010I After 298000 nodes, 22312 on tree, 0.0084597565 best solution, best possible 0 (126777.19 seconds)
# Cbc0010I After 299000 nodes, 22362 on tree, 0.0084597565 best solution, best possible 0 (126817.31 seconds)
# Cbc0010I After 300000 nodes, 22536 on tree, 0.0084597565 best solution, best possible 0 (126855.24 seconds)
# Cbc0010I After 301000 nodes, 22520 on tree, 0.0084597565 best solution, best possible 0 (126899.15 seconds)
# Cbc0010I After 302000 nodes, 22689 on tree, 0.0084597565 best solution, best possible 0 (126937.02 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 258 rows 280 columns
# Cbc0010I After 303000 nodes, 22738 on tree, 0.0084597565 best solution, best possible 0 (126975.88 seconds)
# Cbc0010I After 304000 nodes, 22815 on tree, 0.0084597565 best solution, best possible 0 (127015.80 seconds)
# Cbc0010I After 305000 nodes, 22767 on tree, 0.0084597565 best solution, best possible 0 (127057.17 seconds)
# Cbc0010I After 306000 nodes, 22824 on tree, 0.0084597565 best solution, best possible 0 (127096.71 seconds)
# Cbc0010I After 307000 nodes, 22891 on tree, 0.0084597565 best solution, best possible 0 (127136.56 seconds)
# Cbc0010I After 308000 nodes, 22920 on tree, 0.0084597565 best solution, best possible 0 (127178.34 seconds)
# Cbc0010I After 309000 nodes, 22862 on tree, 0.0084597565 best solution, best possible 0 (127223.35 seconds)
# Cbc0010I After 310000 nodes, 23031 on tree, 0.0084597565 best solution, best possible 0 (127262.00 seconds)
# Cbc0010I After 311000 nodes, 23109 on tree, 0.0084597565 best solution, best possible 0 (127300.15 seconds)
# Cbc0010I After 312000 nodes, 23219 on tree, 0.0084597565 best solution, best possible 0 (127336.31 seconds)
# Cbc0010I After 313000 nodes, 23240 on tree, 0.0084597565 best solution, best possible 0 (127376.37 seconds)
# Cbc0010I After 314000 nodes, 23317 on tree, 0.0084597565 best solution, best possible 0 (127413.85 seconds)
# Cbc0010I After 315000 nodes, 23393 on tree, 0.0084597565 best solution, best possible 0 (127451.30 seconds)
# Cbc0010I After 316000 nodes, 23542 on tree, 0.0084597565 best solution, best possible 0 (127486.82 seconds)
# Cbc0010I After 317000 nodes, 23567 on tree, 0.0084597565 best solution, best possible 0 (127518.00 seconds)
# Cbc0010I After 318000 nodes, 23708 on tree, 0.0084597565 best solution, best possible 0 (127556.20 seconds)
# Cbc0010I After 319000 nodes, 23726 on tree, 0.0084597565 best solution, best possible 0 (127596.81 seconds)
# Cbc0010I After 320000 nodes, 23808 on tree, 0.0084597565 best solution, best possible 0 (127636.01 seconds)
# Cbc0010I After 321000 nodes, 23785 on tree, 0.0084597565 best solution, best possible 0 (127679.74 seconds)
# Cbc0010I After 322000 nodes, 24082 on tree, 0.0084597565 best solution, best possible 0 (127713.29 seconds)
# Cbc0010I After 323000 nodes, 24143 on tree, 0.0084597565 best solution, best possible 0 (128540.41 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 265 rows 290 columns
# Cbc0010I After 324000 nodes, 24197 on tree, 0.0084597565 best solution, best possible 0 (128580.38 seconds)
# Cbc0010I After 325000 nodes, 24188 on tree, 0.0084597565 best solution, best possible 0 (128624.47 seconds)
# Cbc0010I After 326000 nodes, 24253 on tree, 0.0084597565 best solution, best possible 0 (128664.41 seconds)
# Cbc0010I After 327000 nodes, 24319 on tree, 0.0084597565 best solution, best possible 0 (128703.39 seconds)
# Cbc0010I After 328000 nodes, 24352 on tree, 0.0084597565 best solution, best possible 0 (128742.66 seconds)
# Cbc0010I After 329000 nodes, 24303 on tree, 0.0084597565 best solution, best possible 0 (128786.75 seconds)
# Cbc0010I After 330000 nodes, 24406 on tree, 0.0084597565 best solution, best possible 0 (128826.46 seconds)
# Cbc0010I After 331000 nodes, 24627 on tree, 0.0084597565 best solution, best possible 0 (128863.17 seconds)
# Cbc0010I After 332000 nodes, 24903 on tree, 0.0084597565 best solution, best possible 0 (128897.69 seconds)
# Cbc0010I After 333000 nodes, 24896 on tree, 0.0084597565 best solution, best possible 0 (128940.04 seconds)
# Cbc0010I After 334000 nodes, 25049 on tree, 0.0084597565 best solution, best possible 0 (128977.10 seconds)
# Cbc0010I After 335000 nodes, 25153 on tree, 0.0084597565 best solution, best possible 0 (129015.89 seconds)
# Cbc0010I After 336000 nodes, 25342 on tree, 0.0084597565 best solution, best possible 0 (129048.52 seconds)
# Cbc0010I After 337000 nodes, 25294 on tree, 0.0084597565 best solution, best possible 0 (129091.24 seconds)
# Cbc0010I After 338000 nodes, 25367 on tree, 0.0084597565 best solution, best possible 0 (129129.54 seconds)
# Cbc0010I After 339000 nodes, 25398 on tree, 0.0084597565 best solution, best possible 0 (130069.19 seconds)
# Cbc0010I After 340000 nodes, 25461 on tree, 0.0084597565 best solution, best possible 0 (130111.45 seconds)
# Cbc0010I After 341000 nodes, 25399 on tree, 0.0084597565 best solution, best possible 0 (130155.40 seconds)
# Cbc0010I After 342000 nodes, 25502 on tree, 0.0084597565 best solution, best possible 0 (131234.77 seconds)
# Cbc0010I After 343000 nodes, 25532 on tree, 0.0084597565 best solution, best possible 0 (132274.12 seconds)
# Cbc0010I After 344000 nodes, 25535 on tree, 0.0084597565 best solution, best possible 0 (132314.04 seconds)
# Cbc0010I After 345000 nodes, 25457 on tree, 0.0084597565 best solution, best possible 0 (132359.92 seconds)
# Cbc0010I After 346000 nodes, 25471 on tree, 0.0084597565 best solution, best possible 0 (132401.53 seconds)
# Cbc0010I After 347000 nodes, 25455 on tree, 0.0084597565 best solution, best possible 0 (132443.74 seconds)
# Cbc0010I After 348000 nodes, 25506 on tree, 0.0084597565 best solution, best possible 0 (132482.70 seconds)
# Cbc0010I After 349000 nodes, 25450 on tree, 0.0084597565 best solution, best possible 0 (132527.94 seconds)
# Cbc0010I After 350000 nodes, 25559 on tree, 0.0084597565 best solution, best possible 0 (132566.89 seconds)
# Cbc0010I After 351000 nodes, 25577 on tree, 0.0084597565 best solution, best possible 0 (132609.26 seconds)
# Cbc0010I After 352000 nodes, 25665 on tree, 0.0084597565 best solution, best possible 0 (132647.52 seconds)
# Cbc0010I After 353000 nodes, 25683 on tree, 0.0084597565 best solution, best possible 0 (132688.96 seconds)
# Cbc0010I After 354000 nodes, 25771 on tree, 0.0084597565 best solution, best possible 0 (132727.16 seconds)
# Cbc0010I After 355000 nodes, 25870 on tree, 0.0084597565 best solution, best possible 0 (132763.46 seconds)
# Cbc0010I After 356000 nodes, 25920 on tree, 0.0084597565 best solution, best possible 0 (132800.12 seconds)
# Cbc0010I After 357000 nodes, 25908 on tree, 0.0084597565 best solution, best possible 0 (132843.77 seconds)
# Cbc0010I After 358000 nodes, 26010 on tree, 0.0084597565 best solution, best possible 0 (132880.79 seconds)
# Cbc0010I After 359000 nodes, 26068 on tree, 0.0084597565 best solution, best possible 0 (132919.21 seconds)
# Cbc0010I After 360000 nodes, 26149 on tree, 0.0084597565 best solution, best possible 0 (132957.88 seconds)
# Cbc0010I After 361000 nodes, 26095 on tree, 0.0084597565 best solution, best possible 0 (133002.54 seconds)
# Cbc0010I After 362000 nodes, 26098 on tree, 0.0084597565 best solution, best possible 0 (133044.97 seconds)
# Cbc0010I After 363000 nodes, 26119 on tree, 0.0084597565 best solution, best possible 0 (133086.13 seconds)
# Cbc0010I After 364000 nodes, 26169 on tree, 0.0084597565 best solution, best possible 0 (133126.05 seconds)
# Cbc0010I After 365000 nodes, 26134 on tree, 0.0084597565 best solution, best possible 0 (133169.86 seconds)
# Cbc0010I After 366000 nodes, 26236 on tree, 0.0084597565 best solution, best possible 0 (133208.41 seconds)
# Cbc0010I After 367000 nodes, 26305 on tree, 0.0084597565 best solution, best possible 0 (133247.51 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 254 rows 273 columns
# Cbc0010I After 368000 nodes, 26374 on tree, 0.0084597565 best solution, best possible 0 (133287.21 seconds)
# Cbc0010I After 369000 nodes, 26386 on tree, 0.0084597565 best solution, best possible 0 (133331.00 seconds)
# Cbc0010I After 370000 nodes, 26475 on tree, 0.0084597565 best solution, best possible 0 (133367.88 seconds)
# Cbc0010I After 371000 nodes, 26635 on tree, 0.0084597565 best solution, best possible 0 (133403.46 seconds)
# Cbc0010I After 372000 nodes, 26683 on tree, 0.0084597565 best solution, best possible 0 (133441.63 seconds)
# Cbc0010I After 373000 nodes, 26690 on tree, 0.0084597565 best solution, best possible 0 (133483.11 seconds)
# Cbc0010I After 374000 nodes, 26726 on tree, 0.0084597565 best solution, best possible 0 (133523.54 seconds)
# Cbc0010I After 375000 nodes, 26762 on tree, 0.0084597565 best solution, best possible 0 (133563.70 seconds)
# Cbc0010I After 376000 nodes, 26773 on tree, 0.0084597565 best solution, best possible 0 (133604.19 seconds)
# Cbc0010I After 377000 nodes, 26803 on tree, 0.0084597565 best solution, best possible 0 (133646.39 seconds)
# Cbc0010I After 378000 nodes, 26884 on tree, 0.0084597565 best solution, best possible 0 (133685.61 seconds)
# Cbc0010I After 379000 nodes, 26939 on tree, 0.0084597565 best solution, best possible 0 (133725.67 seconds)
# Cbc0010I After 380000 nodes, 27043 on tree, 0.0084597565 best solution, best possible 0 (133761.37 seconds)
# Cbc0010I After 381000 nodes, 27027 on tree, 0.0084597565 best solution, best possible 0 (133804.39 seconds)
# Cbc0010I After 382000 nodes, 27116 on tree, 0.0084597565 best solution, best possible 0 (133844.54 seconds)
# Cbc0010I After 383000 nodes, 27238 on tree, 0.0084597565 best solution, best possible 0 (133880.46 seconds)
# Cbc0010I After 384000 nodes, 27316 on tree, 0.0084597565 best solution, best possible 0 (133917.48 seconds)
# Cbc0010I After 385000 nodes, 27304 on tree, 0.0084597565 best solution, best possible 0 (133960.36 seconds)
# Cbc0010I After 386000 nodes, 27330 on tree, 0.0084597565 best solution, best possible 0 (134001.81 seconds)
# Cbc0010I After 387000 nodes, 27333 on tree, 0.0084597565 best solution, best possible 0 (134043.33 seconds)
# Cbc0010I After 388000 nodes, 27385 on tree, 0.0084597565 best solution, best possible 0 (134082.84 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 268 rows 294 columns
# Cbc0010I After 389000 nodes, 27429 on tree, 0.0084597565 best solution, best possible 0 (134124.68 seconds)
# Cbc0010I After 390000 nodes, 27595 on tree, 0.0084597565 best solution, best possible 0 (134160.56 seconds)
# Cbc0010I After 391000 nodes, 27680 on tree, 0.0084597565 best solution, best possible 0 (134197.74 seconds)
# Cbc0010I After 392000 nodes, 27779 on tree, 0.0084597565 best solution, best possible 0 (134234.13 seconds)
# Cbc0010I After 393000 nodes, 27838 on tree, 0.0084597565 best solution, best possible 0 (134274.75 seconds)
# Cbc0010I After 394000 nodes, 27918 on tree, 0.0084597565 best solution, best possible 0 (134312.27 seconds)
# Cbc0010I After 395000 nodes, 27921 on tree, 0.0084597565 best solution, best possible 0 (134354.37 seconds)
# Cbc0010I After 396000 nodes, 27976 on tree, 0.0084597565 best solution, best possible 0 (134394.22 seconds)
# Cbc0010I After 397000 nodes, 28023 on tree, 0.0084597565 best solution, best possible 0 (134435.62 seconds)
# Cbc0010I After 398000 nodes, 28141 on tree, 0.0084597565 best solution, best possible 0 (134470.95 seconds)
# Cbc0010I After 399000 nodes, 28235 on tree, 0.0084597565 best solution, best possible 0 (134507.12 seconds)
# Cbc0010I After 400000 nodes, 28311 on tree, 0.0084597565 best solution, best possible 0 (134544.67 seconds)
# Cbc0010I After 401000 nodes, 28349 on tree, 0.0084597565 best solution, best possible 0 (134583.83 seconds)
# Cbc0010I After 402000 nodes, 28435 on tree, 0.0084597565 best solution, best possible 0 (134620.28 seconds)
# Cbc0010I After 403000 nodes, 28483 on tree, 0.0084597565 best solution, best possible 0 (134658.94 seconds)
# Cbc0010I After 404000 nodes, 28534 on tree, 0.0084597565 best solution, best possible 0 (134697.10 seconds)
# Cbc0010I After 405000 nodes, 28588 on tree, 0.0084597565 best solution, best possible 0 (134736.22 seconds)
# Cbc0010I After 406000 nodes, 28688 on tree, 0.0084597565 best solution, best possible 0 (134778.36 seconds)
# Cbc0010I After 407000 nodes, 28747 on tree, 0.0084597565 best solution, best possible 0 (134819.61 seconds)
# Cbc0010I After 408000 nodes, 28831 on tree, 0.0084597565 best solution, best possible 0 (134859.55 seconds)
# Cbc0010I After 409000 nodes, 28879 on tree, 0.0084597565 best solution, best possible 0 (134903.10 seconds)
# Cbc0010I After 410000 nodes, 28879 on tree, 0.0084597565 best solution, best possible 0 (134947.29 seconds)
# Cbc0010I After 411000 nodes, 28932 on tree, 0.0084597565 best solution, best possible 0 (134991.63 seconds)
# Cbc0010I After 412000 nodes, 29015 on tree, 0.0084597565 best solution, best possible 0 (135032.90 seconds)
# Cbc0010I After 413000 nodes, 29041 on tree, 0.0084597565 best solution, best possible 0 (135078.38 seconds)
# Cbc0010I After 414000 nodes, 29124 on tree, 0.0084597565 best solution, best possible 0 (135120.48 seconds)
# Cbc0010I After 415000 nodes, 29158 on tree, 0.0084597565 best solution, best possible 0 (135165.26 seconds)
# Cbc0010I After 416000 nodes, 29228 on tree, 0.0084597565 best solution, best possible 0 (135207.77 seconds)
# Cbc0010I After 417000 nodes, 29195 on tree, 0.0084597565 best solution, best possible 0 (135254.91 seconds)
# Cbc0010I After 418000 nodes, 29286 on tree, 0.0084597565 best solution, best possible 0 (135297.13 seconds)
# Cbc0010I After 419000 nodes, 29301 on tree, 0.0084597565 best solution, best possible 0 (135339.29 seconds)
# Cbc0010I After 420000 nodes, 29387 on tree, 0.0084597565 best solution, best possible 0 (135376.16 seconds)
# Cbc0010I After 421000 nodes, 29436 on tree, 0.0084597565 best solution, best possible 0 (135415.76 seconds)
# Cbc0010I After 422000 nodes, 29528 on tree, 0.0084597565 best solution, best possible 0 (135452.55 seconds)
# Cbc0010I After 423000 nodes, 29548 on tree, 0.0084597565 best solution, best possible 0 (135491.62 seconds)
# Cbc0010I After 424000 nodes, 29616 on tree, 0.0084597565 best solution, best possible 0 (135529.54 seconds)
# Cbc0010I After 425000 nodes, 29677 on tree, 0.0084597565 best solution, best possible 0 (135569.90 seconds)
# Cbc0010I After 426000 nodes, 29737 on tree, 0.0084597565 best solution, best possible 0 (135625.11 seconds)
# Cbc0010I After 427000 nodes, 29793 on tree, 0.0084597565 best solution, best possible 0 (135796.81 seconds)
# Cbc0010I After 428000 nodes, 29858 on tree, 0.0084597565 best solution, best possible 0 (135947.40 seconds)
# Cbc0010I After 429000 nodes, 29857 on tree, 0.0084597565 best solution, best possible 0 (136002.19 seconds)
# Cbc0010I After 430000 nodes, 29911 on tree, 0.0084597565 best solution, best possible 0 (136054.44 seconds)
# Cbc0010I After 431000 nodes, 29980 on tree, 0.0084597565 best solution, best possible 0 (136092.09 seconds)
# Cbc0010I After 432000 nodes, 30077 on tree, 0.0084597565 best solution, best possible 0 (136128.87 seconds)
# Cbc0010I After 433000 nodes, 30079 on tree, 0.0084597565 best solution, best possible 0 (136359.79 seconds)
# Cbc0010I After 434000 nodes, 30180 on tree, 0.0084597565 best solution, best possible 0 (136394.68 seconds)
# Cbc0010I After 435000 nodes, 30229 on tree, 0.0084597565 best solution, best possible 0 (136519.85 seconds)
# Cbc0010I After 436000 nodes, 30342 on tree, 0.0084597565 best solution, best possible 0 (136556.34 seconds)
# Cbc0010I After 437000 nodes, 30371 on tree, 0.0084597565 best solution, best possible 0 (136597.01 seconds)
# Cbc0010I After 438000 nodes, 30454 on tree, 0.0084597565 best solution, best possible 0 (136683.43 seconds)
# Cbc0010I After 439000 nodes, 30561 on tree, 0.0084597565 best solution, best possible 0 (136719.66 seconds)
# Cbc0010I After 440000 nodes, 30618 on tree, 0.0084597565 best solution, best possible 0 (136757.84 seconds)
# Cbc0010I After 441000 nodes, 30579 on tree, 0.0084597565 best solution, best possible 0 (136799.06 seconds)
# Cbc0010I After 442000 nodes, 30619 on tree, 0.0084597565 best solution, best possible 0 (136838.01 seconds)
# Cbc0010I After 443000 nodes, 30667 on tree, 0.0084597565 best solution, best possible 0 (136876.12 seconds)
# Cbc0010I After 444000 nodes, 30793 on tree, 0.0084597565 best solution, best possible 0 (136911.33 seconds)
# Cbc0010I After 445000 nodes, 30896 on tree, 0.0084597565 best solution, best possible 0 (136949.02 seconds)
# Cbc0010I After 446000 nodes, 31051 on tree, 0.0084597565 best solution, best possible 0 (136985.09 seconds)
# Cbc0010I After 447000 nodes, 31127 on tree, 0.0084597565 best solution, best possible 0 (137022.39 seconds)
# Cbc0010I After 448000 nodes, 31181 on tree, 0.0084597565 best solution, best possible 0 (137061.53 seconds)
# Cbc0010I After 449000 nodes, 31184 on tree, 0.0084597565 best solution, best possible 0 (137096.17 seconds)
# Cbc0010I After 450000 nodes, 31282 on tree, 0.0084597565 best solution, best possible 0 (137131.66 seconds)
# Cbc0010I After 451000 nodes, 31325 on tree, 0.0084597565 best solution, best possible 0 (137168.50 seconds)
# Cbc0010I After 452000 nodes, 31340 on tree, 0.0084597565 best solution, best possible 0 (137206.82 seconds)
# Cbc0010I After 453000 nodes, 31315 on tree, 0.0084597565 best solution, best possible 0 (137244.64 seconds)
# Cbc0010I After 454000 nodes, 31460 on tree, 0.0084597565 best solution, best possible 0 (137278.73 seconds)
# Cbc0010I After 455000 nodes, 31564 on tree, 0.0084597565 best solution, best possible 0 (137314.10 seconds)
# Cbc0010I After 456000 nodes, 31695 on tree, 0.0084597565 best solution, best possible 0 (137350.15 seconds)
# Cbc0010I After 457000 nodes, 31675 on tree, 0.0084597565 best solution, best possible 0 (137387.55 seconds)
# Cbc0010I After 458000 nodes, 31891 on tree, 0.0084597565 best solution, best possible 0 (137423.40 seconds)
# Cbc0010I After 459000 nodes, 31922 on tree, 0.0084597565 best solution, best possible 0 (137461.12 seconds)
# Cbc0010I After 460000 nodes, 32017 on tree, 0.0084597565 best solution, best possible 0 (137496.27 seconds)
# Cbc0010I After 461000 nodes, 32184 on tree, 0.0084597565 best solution, best possible 0 (137529.46 seconds)
# ...
# Cbc0010I After 2429000 nodes, 39487 on tree, 0.0084597565 best solution, best possible 0 (395624.01 seconds)
# Cbc0010I After 2430000 nodes, 39488 on tree, 0.0084597565 best solution, best possible 0 (395653.20 seconds)
# Cbc0010I After 2431000 nodes, 39501 on tree, 0.0084597565 best solution, best possible 0 (395685.44 seconds)
# Cbc0010I After 2432000 nodes, 39507 on tree, 0.0084597565 best solution, best possible 0 (395717.06 seconds)
# Cbc0010I After 2433000 nodes, 39548 on tree, 0.0084597565 best solution, best possible 0 (395749.32 seconds)
# Cbc0010I After 2434000 nodes, 39449 on tree, 0.0084597565 best solution, best possible 0 (395782.12 seconds)
# Cbc0010I After 2435000 nodes, 39540 on tree, 0.0084597565 best solution, best possible 0 (395817.18 seconds)
# Cbc0010I After 2436000 nodes, 39482 on tree, 0.0084597565 best solution, best possible 0 (395853.45 seconds)
# Cbc0010I After 2437000 nodes, 39464 on tree, 0.0084597565 best solution, best possible 0 (395889.23 seconds)
# Cbc0010I After 2438000 nodes, 39433 on tree, 0.0084597565 best solution, best possible 0 (395925.00 seconds)
# Cbc0010I After 2439000 nodes, 39527 on tree, 0.0084597565 best solution, best possible 0 (395962.98 seconds)
# Cbc0010I After 2440000 nodes, 39518 on tree, 0.0084597565 best solution, best possible 0 (395999.22 seconds)
# Cbc0010I After 2441000 nodes, 39423 on tree, 0.0084597565 best solution, best possible 0 (396032.96 seconds)
# Cbc0010I After 2442000 nodes, 39424 on tree, 0.0084597565 best solution, best possible 0 (396072.94 seconds)
# Cbc0010I After 2443000 nodes, 39354 on tree, 0.0084597565 best solution, best possible 0 (396117.43 seconds)
# Cbc0010I After 2444000 nodes, 39213 on tree, 0.0084597565 best solution, best possible 0 (396160.87 seconds)
# Cbc0010I After 2445000 nodes, 39318 on tree, 0.0084597565 best solution, best possible 0 (396204.99 seconds)
# Cbc0010I After 2446000 nodes, 39237 on tree, 0.0084597565 best solution, best possible 0 (396242.17 seconds)
# Cbc0010I After 2447000 nodes, 39307 on tree, 0.0084597565 best solution, best possible 0 (396273.18 seconds)
# Cbc0010I After 2448000 nodes, 39287 on tree, 0.0084597565 best solution, best possible 0 (396300.47 seconds)
# Cbc0010I After 2449000 nodes, 39269 on tree, 0.0084597565 best solution, best possible 0 (396333.76 seconds)
# Cbc0010I After 2450000 nodes, 39280 on tree, 0.0084597565 best solution, best possible 0 (396367.79 seconds)
# Cbc0010I After 2451000 nodes, 39263 on tree, 0.0084597565 best solution, best possible 0 (396403.22 seconds)
# Cbc0010I After 2452000 nodes, 39251 on tree, 0.0084597565 best solution, best possible 0 (396437.78 seconds)
# Cbc0010I After 2453000 nodes, 39265 on tree, 0.0084597565 best solution, best possible 0 (396473.76 seconds)
# Cbc0010I After 2454000 nodes, 39251 on tree, 0.0084597565 best solution, best possible 0 (396510.78 seconds)
# Cbc0010I After 2455000 nodes, 39326 on tree, 0.0084597565 best solution, best possible 0 (396546.35 seconds)
# Cbc0010I After 2456000 nodes, 39263 on tree, 0.0084597565 best solution, best possible 0 (396582.54 seconds)
# Cbc0010I After 2457000 nodes, 39245 on tree, 0.0084597565 best solution, best possible 0 (396620.71 seconds)
# Cbc0010I After 2458000 nodes, 39264 on tree, 0.0084597565 best solution, best possible 0 (396657.07 seconds)
# Cbc0010I After 2459000 nodes, 39288 on tree, 0.0084597565 best solution, best possible 0 (396691.44 seconds)
# Cbc0010I After 2460000 nodes, 39280 on tree, 0.0084597565 best solution, best possible 0 (396720.49 seconds)
# Cbc0010I After 2461000 nodes, 39307 on tree, 0.0084597565 best solution, best possible 0 (396756.52 seconds)
# Cbc0010I After 2462000 nodes, 39246 on tree, 0.0084597565 best solution, best possible 0 (396795.17 seconds)
# Cbc0010I After 2463000 nodes, 39265 on tree, 0.0084597565 best solution, best possible 0 (396834.45 seconds)
# Cbc0010I After 2464000 nodes, 39282 on tree, 0.0084597565 best solution, best possible 0 (396874.00 seconds)
# Cbc0010I After 2465000 nodes, 39234 on tree, 0.0084597565 best solution, best possible 0 (396916.87 seconds)
# Cbc0010I After 2466000 nodes, 39316 on tree, 0.0084597565 best solution, best possible 0 (396957.45 seconds)
# Cbc0010I After 2467000 nodes, 39288 on tree, 0.0084597565 best solution, best possible 0 (396998.42 seconds)
# Cbc0010I After 2468000 nodes, 39240 on tree, 0.0084597565 best solution, best possible 0 (397043.72 seconds)
# Cbc0010I After 2469000 nodes, 39264 on tree, 0.0084597565 best solution, best possible 0 (397078.65 seconds)
# Cbc0010I After 2470000 nodes, 39292 on tree, 0.0084597565 best solution, best possible 0 (397120.52 seconds)
# Cbc0010I After 2471000 nodes, 39209 on tree, 0.0084597565 best solution, best possible 0 (397161.49 seconds)
# Cbc0010I After 2472000 nodes, 39232 on tree, 0.0084597565 best solution, best possible 0 (397204.84 seconds)
# Cbc0010I After 2473000 nodes, 39290 on tree, 0.0084597565 best solution, best possible 0 (397240.04 seconds)
# Cbc0010I After 2474000 nodes, 39281 on tree, 0.0084597565 best solution, best possible 0 (397275.64 seconds)
# Cbc0010I After 2475000 nodes, 39288 on tree, 0.0084597565 best solution, best possible 0 (397313.04 seconds)
# Cbc0010I After 2476000 nodes, 39276 on tree, 0.0084597565 best solution, best possible 0 (397351.40 seconds)
# Cbc0010I After 2477000 nodes, 39260 on tree, 0.0084597565 best solution, best possible 0 (397390.60 seconds)
# Cbc0010I After 2478000 nodes, 39244 on tree, 0.0084597565 best solution, best possible 0 (397430.31 seconds)
# Cbc0010I After 2479000 nodes, 39266 on tree, 0.0084597565 best solution, best possible 0 (397472.32 seconds)
# Cbc0010I After 2480000 nodes, 39294 on tree, 0.0084597565 best solution, best possible 0 (397517.53 seconds)
# Cbc0010I After 2481000 nodes, 39253 on tree, 0.0084597565 best solution, best possible 0 (397561.04 seconds)
# Cbc0010I After 2482000 nodes, 39239 on tree, 0.0084597565 best solution, best possible 0 (397606.37 seconds)
# Cbc0010I After 2483000 nodes, 39274 on tree, 0.0084597565 best solution, best possible 0 (397649.14 seconds)
# Cbc0010I After 2484000 nodes, 39237 on tree, 0.0084597565 best solution, best possible 0 (397695.63 seconds)
# Cbc0010I After 2485000 nodes, 39274 on tree, 0.0084597565 best solution, best possible 0 (397740.90 seconds)
# Cbc0010I After 2486000 nodes, 39237 on tree, 0.0084597565 best solution, best possible 0 (397786.44 seconds)
# Cbc0010I After 2487000 nodes, 39278 on tree, 0.0084597565 best solution, best possible 0 (397832.74 seconds)
# Cbc0010I After 2488000 nodes, 39295 on tree, 0.0084597565 best solution, best possible 0 (397876.25 seconds)
# Cbc0010I After 2489000 nodes, 39262 on tree, 0.0084597565 best solution, best possible 0 (397915.65 seconds)
# Cbc0010I After 2490000 nodes, 39210 on tree, 0.0084597565 best solution, best possible 0 (397954.81 seconds)
# Cbc0010I After 2491000 nodes, 39291 on tree, 0.0084597565 best solution, best possible 0 (397993.20 seconds)
# Cbc0010I After 2492000 nodes, 39225 on tree, 0.0084597565 best solution, best possible 0 (398032.09 seconds)
# Cbc0010I After 2493000 nodes, 39226 on tree, 0.0084597565 best solution, best possible 0 (398073.19 seconds)
# Cbc0010I After 2494000 nodes, 39227 on tree, 0.0084597565 best solution, best possible 0 (398116.42 seconds)
# Cbc0010I After 2495000 nodes, 39258 on tree, 0.0084597565 best solution, best possible 0 (398162.51 seconds)
# Cbc0010I After 2496000 nodes, 39241 on tree, 0.0084597565 best solution, best possible 0 (398204.23 seconds)
# Cbc0010I After 2497000 nodes, 39303 on tree, 0.0084597565 best solution, best possible 0 (398248.94 seconds)
# Cbc0010I After 2498000 nodes, 39305 on tree, 0.0084597565 best solution, best possible 0 (398289.71 seconds)
# Cbc0010I After 2499000 nodes, 39306 on tree, 0.0084597565 best solution, best possible 0 (398317.23 seconds)
# Cbc0010I After 2500000 nodes, 39305 on tree, 0.0084597565 best solution, best possible 0 (398351.58 seconds)
# Cbc0010I After 2501000 nodes, 39265 on tree, 0.0084597565 best solution, best possible 0 (398389.34 seconds)
# Cbc0010I After 2502000 nodes, 39298 on tree, 0.0084597565 best solution, best possible 0 (398427.45 seconds)
# Cbc0010I After 2503000 nodes, 39291 on tree, 0.0084597565 best solution, best possible 0 (398467.28 seconds)
# Cbc0010I After 2504000 nodes, 39268 on tree, 0.0084597565 best solution, best possible 0 (398506.36 seconds)
# Cbc0010I After 2505000 nodes, 39257 on tree, 0.0084597565 best solution, best possible 0 (398545.44 seconds)
# Cbc0010I After 2506000 nodes, 39283 on tree, 0.0084597565 best solution, best possible 0 (398585.91 seconds)
# Cbc0010I After 2507000 nodes, 39274 on tree, 0.0084597565 best solution, best possible 0 (398632.83 seconds)
# Cbc0010I After 2508000 nodes, 39253 on tree, 0.0084597565 best solution, best possible 0 (398681.31 seconds)
# Cbc0010I After 2509000 nodes, 39244 on tree, 0.0084597565 best solution, best possible 0 (398728.26 seconds)
# Cbc0010I After 2510000 nodes, 39285 on tree, 0.0084597565 best solution, best possible 0 (398778.64 seconds)
# Cbc0010I After 2511000 nodes, 39237 on tree, 0.0084597565 best solution, best possible 0 (398825.36 seconds)
# Cbc0010I After 2512000 nodes, 39256 on tree, 0.0084597565 best solution, best possible 0 (398876.19 seconds)
# Cbc0010I After 2513000 nodes, 39221 on tree, 0.0084597565 best solution, best possible 0 (398927.83 seconds)
# Cbc0010I After 2514000 nodes, 39303 on tree, 0.0084597565 best solution, best possible 0 (398976.09 seconds)
# Cbc0010I After 2515000 nodes, 39300 on tree, 0.0084597565 best solution, best possible 0 (399027.40 seconds)
# Cbc0010I After 2516000 nodes, 39292 on tree, 0.0084597565 best solution, best possible 0 (399059.32 seconds)
# Cbc0010I After 2517000 nodes, 39285 on tree, 0.0084597565 best solution, best possible 0 (399100.37 seconds)
# Cbc0010I After 2518000 nodes, 39293 on tree, 0.0084597565 best solution, best possible 0 (399142.60 seconds)
# Cbc0010I After 2519000 nodes, 39312 on tree, 0.0084597565 best solution, best possible 0 (399187.25 seconds)
# Cbc0010I After 2520000 nodes, 39246 on tree, 0.0084597565 best solution, best possible 0 (399234.11 seconds)
# Cbc0010I After 2521000 nodes, 39271 on tree, 0.0084597565 best solution, best possible 0 (399281.93 seconds)
# Cbc0010I After 2522000 nodes, 39256 on tree, 0.0084597565 best solution, best possible 0 (399324.90 seconds)
# Cbc0010I After 2523000 nodes, 39247 on tree, 0.0084597565 best solution, best possible 0 (399372.57 seconds)
# Cbc0010I After 2524000 nodes, 39306 on tree, 0.0084597565 best solution, best possible 0 (399421.67 seconds)
# Cbc0010I After 2525000 nodes, 39253 on tree, 0.0084597565 best solution, best possible 0 (399466.80 seconds)
# Cbc0010I After 2526000 nodes, 39280 on tree, 0.0084597565 best solution, best possible 0 (399502.39 seconds)
# Cbc0010I After 2527000 nodes, 39264 on tree, 0.0084597565 best solution, best possible 0 (399541.16 seconds)
# Cbc0010I After 2528000 nodes, 39270 on tree, 0.0084597565 best solution, best possible 0 (399581.28 seconds)
# Cbc0010I After 2529000 nodes, 39278 on tree, 0.0084597565 best solution, best possible 0 (399621.60 seconds)
# Cbc0010I After 2530000 nodes, 39307 on tree, 0.0084597565 best solution, best possible 0 (399663.98 seconds)
# Cbc0010I After 2531000 nodes, 39259 on tree, 0.0084597565 best solution, best possible 0 (399706.59 seconds)
# Cbc0010I After 2532000 nodes, 39258 on tree, 0.0084597565 best solution, best possible 0 (399750.80 seconds)
# Cbc0010I After 2533000 nodes, 39289 on tree, 0.0084597565 best solution, best possible 0 (399794.07 seconds)
# Cbc0010I After 2534000 nodes, 39295 on tree, 0.0084597565 best solution, best possible 0 (399838.41 seconds)
# Cbc0010I After 2535000 nodes, 39307 on tree, 0.0084597565 best solution, best possible 0 (399883.33 seconds)
# Cbc0010I After 2536000 nodes, 39267 on tree, 0.0084597565 best solution, best possible 0 (399923.27 seconds)
# Cbc0010I After 2537000 nodes, 39286 on tree, 0.0084597565 best solution, best possible 0 (399961.50 seconds)
# Cbc0010I After 2538000 nodes, 39252 on tree, 0.0084597565 best solution, best possible 0 (400002.22 seconds)
# Cbc0010I After 2539000 nodes, 39237 on tree, 0.0084597565 best solution, best possible 0 (400046.66 seconds)
# Cbc0010I After 2540000 nodes, 39260 on tree, 0.0084597565 best solution, best possible 0 (400089.18 seconds)
# Cbc0010I After 2541000 nodes, 39281 on tree, 0.0084597565 best solution, best possible 0 (400133.53 seconds)
# Cbc0010I After 2542000 nodes, 39240 on tree, 0.0084597565 best solution, best possible 0 (401098.28 seconds)
# Cbc0010I After 2543000 nodes, 39217 on tree, 0.0084597565 best solution, best possible 0 (401142.29 seconds)
# Cbc0010I After 2544000 nodes, 39291 on tree, 0.0084597565 best solution, best possible 0 (402172.44 seconds)
# Cbc0010I After 2545000 nodes, 39289 on tree, 0.0084597565 best solution, best possible 0 (402766.40 seconds)
# Cbc0010I After 2546000 nodes, 39317 on tree, 0.0084597565 best solution, best possible 0 (402798.77 seconds)
# Cbc0010I After 2547000 nodes, 39287 on tree, 0.0084597565 best solution, best possible 0 (402835.40 seconds)
# Cbc0010I After 2548000 nodes, 39283 on tree, 0.0084597565 best solution, best possible 0 (402871.27 seconds)
# Cbc0010I After 2549000 nodes, 39249 on tree, 0.0084597565 best solution, best possible 0 (402907.24 seconds)
# Cbc0010I After 2550000 nodes, 39236 on tree, 0.0084597565 best solution, best possible 0 (402947.85 seconds)
# Cbc0010I After 2551000 nodes, 39261 on tree, 0.0084597565 best solution, best possible 0 (402988.57 seconds)
# Cbc0010I After 2552000 nodes, 39234 on tree, 0.0084597565 best solution, best possible 0 (403029.71 seconds)
# Cbc0010I After 2553000 nodes, 39232 on tree, 0.0084597565 best solution, best possible 0 (403071.02 seconds)
# Cbc0010I After 2554000 nodes, 39316 on tree, 0.0084597565 best solution, best possible 0 (403113.40 seconds)
# Cbc0010I After 2555000 nodes, 39243 on tree, 0.0084597565 best solution, best possible 0 (403156.89 seconds)
# Cbc0010I After 2556000 nodes, 39258 on tree, 0.0084597565 best solution, best possible 0 (403199.37 seconds)
# Cbc0010I After 2557000 nodes, 39219 on tree, 0.0084597565 best solution, best possible 0 (403244.35 seconds)
# Cbc0010I After 2558000 nodes, 39290 on tree, 0.0084597565 best solution, best possible 0 (403280.87 seconds)
# Cbc0010I After 2559000 nodes, 39289 on tree, 0.0084597565 best solution, best possible 0 (403309.90 seconds)
# Cbc0010I After 2560000 nodes, 39248 on tree, 0.0084597565 best solution, best possible 0 (403346.27 seconds)
# Cbc0010I After 2561000 nodes, 39303 on tree, 0.0084597565 best solution, best possible 0 (403386.12 seconds)
# Cbc0010I After 2562000 nodes, 39280 on tree, 0.0084597565 best solution, best possible 0 (403427.03 seconds)
# Cbc0010I After 2563000 nodes, 39256 on tree, 0.0084597565 best solution, best possible 0 (403467.72 seconds)
# Cbc0010I After 2564000 nodes, 39256 on tree, 0.0084597565 best solution, best possible 0 (403508.31 seconds)
# Cbc0010I After 2565000 nodes, 39233 on tree, 0.0084597565 best solution, best possible 0 (403549.16 seconds)
# Cbc0010I After 2566000 nodes, 39278 on tree, 0.0084597565 best solution, best possible 0 (403591.78 seconds)
# Cbc0010I After 2567000 nodes, 39291 on tree, 0.0084597565 best solution, best possible 0 (403634.37 seconds)
# Cbc0010I After 2568000 nodes, 39258 on tree, 0.0084597565 best solution, best possible 0 (403677.06 seconds)
# Cbc0010I After 2569000 nodes, 39261 on tree, 0.0084597565 best solution, best possible 0 (403718.62 seconds)
# Cbc0010I After 2570000 nodes, 39292 on tree, 0.0084597565 best solution, best possible 0 (403749.21 seconds)
# Cbc0010I After 2571000 nodes, 39297 on tree, 0.0084597565 best solution, best possible 0 (403778.07 seconds)
# Cbc0010I After 2572000 nodes, 39298 on tree, 0.0084597565 best solution, best possible 0 (403811.00 seconds)
# Cbc0010I After 2573000 nodes, 39290 on tree, 0.0084597565 best solution, best possible 0 (403847.14 seconds)
# Cbc0010I After 2574000 nodes, 39287 on tree, 0.0084597565 best solution, best possible 0 (403882.10 seconds)
# Cbc0010I After

# %%
out_of_sample_year_start
# Out:
# {1: '2019-07-01',
#  2: '2020-07-01',
#  3: '2021-07-01',
#  4: '2022-07-01',
#  5: '2023-07-01'}
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l4/hkz5jfdx3t581gbl8x7mfqs40000gn/T/a3ea6d31818d46adba9114d5757086c0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/l4/hkz5jfdx3t581gbl8x7mfqs40000gn/T/a3ea6d31818d46adba9114d5757086c0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 2450 COLUMNS
# At line 63987 RHS
# At line 66433 BOUNDS
# At line 66899 ENDATA
# Problem MODEL has 2445 rows, 2383 columns and 60548 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.10 seconds
# Cgl0004I processed model has 1050 rows, 1453 columns (465 integer (465 of which binary)) and 57758 elements
# Cbc0038I Initial state - 59 integers unsatisfied sum - 1
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 3.27653 iterations 828
# Cbc0038I Solution found of 3.27653
# Cbc0038I Relaxing continuous gives 3.27653
# Cbc0038I Before mini branch and bound, 406 integers at bound fixed and 812 continuous
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 238 rows 235 columns
# Cbc0038I Mini branch and bound improved solution from 3.27653 to 0.0303079 (0.57 seconds)
# Cbc0038I Freeing continuous variables gives a solution of 0.0303079
# Cbc0038I Round again with cutoff of 0.0272681
# Cbc0038I Pass   2: suminf.    1.00000 (52) obj. 0.0272681 iterations 219
# Cbc0038I Pass   3: suminf.    0.10373 (26) obj. 0.0272681 iterations 592
# Cbc0038I Pass   4: suminf.    0.00005 (1) obj. 0.0272681 iterations 286
# Cbc0038I Pass   5: suminf.    0.00005 (1) obj. 0.0272681 iterations 0
# Cbc0038I Pass   6: suminf.    1.00000 (29) obj. 0.0272681 iterations 519
# Cbc0038I Pass   7: suminf.    0.22599 (24) obj. 0.0272681 iterations 468
# Cbc0038I Pass   8: suminf.    0.55855 (17) obj. 0.0272681 iterations 166
# Cbc0038I Pass   9: suminf.    0.32027 (21) obj. 0.0272681 iterations 287
# Cbc0038I Pass  10: suminf.    0.34727 (12) obj. 0.0272681 iterations 186
# Cbc0038I Pass  11: suminf.    0.22013 (17) obj. 0.0272681 iterations 150
# Cbc0038I Pass  12: suminf.    0.28914 (13) obj. 0.0272681 iterations 192
# Cbc0038I Pass  13: suminf.    0.22599 (15) obj. 0.0272681 iterations 123
# Cbc0038I Pass  14: suminf.    0.22317 (11) obj. 0.0272681 iterations 154
# Cbc0038I Pass  15: suminf.    0.20184 (15) obj. 0.0272681 iterations 72
# Cbc0038I Pass  16: suminf.    0.27262 (9) obj. 0.0272681 iterations 144
# Cbc0038I Pass  17: suminf.    0.20007 (17) obj. 0.0272681 iterations 173
# Cbc0038I Pass  18: suminf.    0.31166 (15) obj. 0.0272681 iterations 192
# Cbc0038I Pass  19: suminf.    0.23405 (17) obj. 0.0272681 iterations 206
# Cbc0038I Pass  20: suminf.    0.27958 (13) obj. 0.0272681 iterations 139
# Cbc0038I Pass  21: suminf.    0.23154 (22) obj. 0.0272681 iterations 112
# Cbc0038I Pass  22: suminf.    0.35729 (15) obj. 0.0272681 iterations 151
# Cbc0038I Pass  23: suminf.    0.24596 (21) obj. 0.0272681 iterations 200
# Cbc0038I Pass  24: suminf.    0.29025 (16) obj. 0.0272681 iterations 174
# Cbc0038I Pass  25: suminf.    0.25145 (17) obj. 0.0272681 iterations 112
# Cbc0038I Pass  26: suminf.    0.27322 (16) obj. 0.0272681 iterations 112
# Cbc0038I Pass  27: suminf.    0.24460 (18) obj. 0.0272681 iterations 85
# Cbc0038I Pass  28: suminf.    0.30778 (14) obj. 0.0272681 iterations 160
# Cbc0038I Pass  29: suminf.    1.00000 (34) obj. 0.0272681 iterations 388
# Cbc0038I Pass  30: suminf.    0.30906 (29) obj. 0.0272681 iterations 183
# Cbc0038I Pass  31: suminf.    0.49135 (18) obj. 0.0272681 iterations 167
# Cbc0038I Rounding solution of 0.0272681 is better than previous of 0.0303079
#
# Cbc0038I Before mini branch and bound, 231 integers at bound fixed and 488 continuous
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 564 rows 720 columns - 1 fixed gives 563, 719 - still too large
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 559 rows 719 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (1.89 seconds)
# Cbc0038I Round again with cutoff of 0.0218065
# Cbc0038I Pass  31: suminf.    1.00000 (52) obj. 0.0218065 iterations 15
# Cbc0038I Pass  32: suminf.    0.16106 (32) obj. 0.0218065 iterations 752
# Cbc0038I Pass  33: suminf.    0.00000 (0) obj. 0.0218065 iterations 262
# Cbc0038I Solution found of 0.0218065
# Cbc0038I Relaxing continuous gives 0.0201214
# Cbc0038I Before mini branch and bound, 355 integers at bound fixed and 746 continuous
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 304 rows 352 columns
# Cbc0038I Mini branch and bound did not improve solution (2.49 seconds)
# Cbc0038I Freeing continuous variables gives a solution of 0.0191141
# Cbc0038I Round again with cutoff of 0.0133729
# Cbc0038I Pass  34: suminf.    1.00000 (54) obj. 0.0133729 iterations 19
# Cbc0038I Pass  35: suminf.    0.16872 (34) obj. 0.0133729 iterations 707
# Cbc0038I Pass  36: suminf.    0.00096 (2) obj. 0.0133729 iterations 325
# Cbc0038I Pass  37: suminf.    0.00096 (2) obj. 0.0133729 iterations 0
# Cbc0038I Pass  38: suminf.    1.00000 (33) obj. 0.0133729 iterations 553
# Cbc0038I Pass  39: suminf.    0.27080 (25) obj. 0.0133729 iterations 311
# Cbc0038I Pass  40: suminf.    0.45781 (19) obj. 0.0133729 iterations 237
# Cbc0038I Pass  41: suminf.    0.26151 (21) obj. 0.0133729 iterations 166
# Cbc0038I Pass  42: suminf.    0.27578 (11) obj. 0.0133729 iterations 228
# Cbc0038I Pass  43: suminf.    0.18288 (17) obj. 0.0133729 iterations 170
# Cbc0038I Pass  44: suminf.    0.28660 (13) obj. 0.0133729 iterations 142
# Cbc0038I Pass  45: suminf.    0.21748 (13) obj. 0.0133729 iterations 150
# Cbc0038I Pass  46: suminf.    0.29019 (12) obj. 0.0133729 iterations 155
# Cbc0038I Pass  47: suminf.    0.23848 (16) obj. 0.0133729 iterations 153
# Cbc0038I Pass  48: suminf.    0.22794 (9) obj. 0.0133729 iterations 140
# Cbc0038I Pass  49: suminf.    0.20348 (15) obj. 0.0133729 iterations 90
# Cbc0038I Pass  50: suminf.    0.16791 (14) obj. 0.0133729 iterations 135
# Cbc0038I Pass  51: suminf.    0.14324 (14) obj. 0.0133729 iterations 98
# Cbc0038I Pass  52: suminf.    0.23687 (16) obj. 0.0133729 iterations 192
# Cbc0038I Pass  53: suminf.    0.21408 (17) obj. 0.0133729 iterations 96
# Cbc0038I Pass  54: suminf.    0.29368 (16) obj. 0.0133729 iterations 128
# Cbc0038I Pass  55: suminf.    0.25815 (19) obj. 0.0133729 iterations 88
# Cbc0038I Pass  56: suminf.    0.27709 (14) obj. 0.0133729 iterations 157
# Cbc0038I Pass  57: suminf.    0.22277 (17) obj. 0.0133729 iterations 102
# Cbc0038I Pass  58: suminf.    0.23431 (13) obj. 0.0133729 iterations 89
# Cbc0038I Pass  59: suminf.    0.18227 (15) obj. 0.0133729 iterations 107
# Cbc0038I Pass  60: suminf.    0.18438 (9) obj. 0.0133729 iterations 131
# Cbc0038I Pass  61: suminf.    0.17137 (16) obj. 0.0133729 iterations 82
# Cbc0038I Pass  62: suminf.    0.18329 (12) obj. 0.0133729 iterations 148
# Cbc0038I Pass  63: suminf.    0.16218 (14) obj. 0.0133729 iterations 101
# Cbc0038I Rounding solution of 0.0133729 is better than previous of 0.0191141
#
# Cbc0038I Before mini branch and bound, 263 integers at bound fixed and 535 continuous
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 508 rows 644 columns
# Cbc0038I Mini branch and bound did not improve solution (4.71 seconds)
# Cbc0038I Round again with cutoff of 0.00935401
# Cbc0038I Pass  63: suminf.    1.00000 (55) obj. 0.00935401 iterations 22
# Cbc0038I Pass  64: suminf.    0.15262 (35) obj. 0.00935401 iterations 544
# Cbc0038I Pass  65: suminf.    0.01983 (15) obj. 0.00935401 iterations 270
# Cbc0038I Pass  66: suminf.    0.00151 (5) obj. 0.00935401 iterations 170
# Cbc0038I Pass  67: suminf.    0.00151 (5) obj. 0.00935401 iterations 0
# Cbc0038I Pass  68: suminf.    1.00000 (33) obj. 0.00935401 iterations 480
# Cbc0038I Pass  69: suminf.    0.33760 (30) obj. 0.00935401 iterations 302
# Cbc0038I Pass  70: suminf.    0.64592 (20) obj. 0.00935401 iterations 180
# Cbc0038I Pass  71: suminf.    0.46242 (24) obj. 0.00935401 iterations 223
# Cbc0038I Pass  72: suminf.    0.55462 (19) obj. 0.00935401 iterations 146
# Cbc0038I Pass  73: suminf.    0.44620 (26) obj. 0.00935401 iterations 144
# Cbc0038I Pass  74: suminf.    0.48763 (19) obj. 0.00935401 iterations 199
# Cbc0038I Pass  75: suminf.    0.40475 (24) obj. 0.00935401 iterations 169
# Cbc0038I Pass  76: suminf.    0.42661 (18) obj. 0.00935401 iterations 206
# Cbc0038I Pass  77: suminf.    0.37353 (22) obj. 0.00935401 iterations 223
# Cbc0038I Pass  78: suminf.    0.50843 (21) obj. 0.00935401 iterations 220
# Cbc0038I Pass  79: suminf.    0.40892 (20) obj. 0.00935401 iterations 205
# Cbc0038I Pass  80: suminf.    0.39223 (16) obj. 0.00935401 iterations 107
# Cbc0038I Pass  81: suminf.    0.37274 (21) obj. 0.00935401 iterations 84
# Cbc0038I Pass  82: suminf.    0.43537 (16) obj. 0.00935401 iterations 159
# Cbc0038I Pass  83: suminf.    0.39229 (20) obj. 0.00935401 iterations 151
# Cbc0038I Pass  84: suminf.    0.40672 (17) obj. 0.00935401 iterations 167
# Cbc0038I Pass  85: suminf.    0.93496 (31) obj. 0.00935401 iterations 395
# Cbc0038I Pass  86: suminf.    0.49185 (26) obj. 0.00935401 iterations 212
# Cbc0038I Pass  87: suminf.    0.50510 (19) obj. 0.00935401 iterations 225
# Cbc0038I Pass  88: suminf.    0.34384 (21) obj. 0.00935401 iterations 134
# Cbc0038I Pass  89: suminf.    0.33658 (15) obj. 0.00935401 iterations 155
# Cbc0038I Pass  90: suminf.    0.26913 (24) obj. 0.00935401 iterations 137
# Cbc0038I Pass  91: suminf.    0.25526 (15) obj. 0.00935401 iterations 181
# Cbc0038I Pass  92: suminf.    0.23516 (20) obj. 0.00935401 iterations 66
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 231 integers at bound fixed and 480 continuous
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 580 rows 736 columns - 1 fixed gives 579, 735 - still too large
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 567 rows 735 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (5.96 seconds)
# Cbc0038I After 5.96 seconds - Feasibility pump exiting with objective of 0.0133729 - took 5.70 seconds
# Cbc0012I Integer solution of 0.012416455 found by feasibility pump after 0 iterations and 0 nodes (6.08 seconds)
# Cbc0012I Integer solution of 0.012261277 found by DiveCoefficient after 0 iterations and 0 nodes (7.38 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 240 rows 238 columns
# Cbc0012I Integer solution of 0.012247815 found by DiveCoefficient after 1649 iterations and 0 nodes (10.79 seconds)
# Cbc0031I 36 added rows had average density of 604.27778
# Cbc0013I At root node, 36 cuts changed objective from 0 to 0 in 10 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.077 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 346 row cuts average 620.2 elements, 0 column cuts (0 active)  in 1.067 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.066 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 0.012247815 best solution, best possible 0 (11.10 seconds)
# Cbc0012I Integer solution of 0.012063388 found by DiveCoefficient after 1828 iterations and 1 nodes (12.76 seconds)
# Cbc0012I Integer solution of 0.011486656 found by DiveCoefficient after 1934 iterations and 2 nodes (14.33 seconds)
# Cbc0012I Integer solution of 0.0093455599 found by DiveCoefficient after 1934 iterations and 2 nodes (16.23 seconds)
# Cbc0012I Integer solution of 0.0087863833 found by DiveCoefficient after 2004 iterations and 3 nodes (17.86 seconds)
# Cbc0012I Integer solution of 0.0084597565 found by DiveCoefficient after 2008 iterations and 3 nodes (19.57 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 253 rows 262 columns
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 232 rows 237 columns
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 256 rows 276 columns
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 242 rows 256 columns
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 247 rows 263 columns
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 244 rows 259 columns
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 247 rows 263 columns
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 246 rows 261 columns
# Cbc0010I After 1000 nodes, 156 on tree, 0.0084597565 best solution, best possible 0 (63.39 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 264 rows 288 columns
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 278 rows 309 columns
# Cbc0010I After 2000 nodes, 198 on tree, 0.0084597565 best solution, best possible 0 (104.10 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 263 rows 287 columns
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 279 rows 311 columns
# Cbc0010I After 3000 nodes, 244 on tree, 0.0084597565 best solution, best possible 0 (142.95 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 259 rows 281 columns
# Cbc0010I After 4000 nodes, 296 on tree, 0.0084597565 best solution, best possible 0 (180.05 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 281 rows 314 columns
# Cbc0010I After 5000 nodes, 357 on tree, 0.0084597565 best solution, best possible 0 (218.18 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 283 rows 317 columns
# Cbc0010I After 6000 nodes, 195 on tree, 0.0084597565 best solution, best possible 0 (259.28 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 261 rows 285 columns
# Cbc0010I After 7000 nodes, 223 on tree, 0.0084597565 best solution, best possible 0 (293.88 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 285 rows 320 columns
# Cbc0010I After 8000 nodes, 201 on tree, 0.0084597565 best solution, best possible 0 (334.49 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 271 rows 299 columns
# Cbc0010I After 9000 nodes, 326 on tree, 0.0084597565 best solution, best possible 0 (359.03 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 288 rows 324 columns
# Cbc0010I After 10000 nodes, 503 on tree, 0.0084597565 best solution, best possible 0 (381.24 seconds)
# Cbc0010I After 11000 nodes, 487 on tree, 0.0084597565 best solution, best possible 0 (409.56 seconds)
# Cbc0010I After 12000 nodes, 670 on tree, 0.0084597565 best solution, best possible 0 (444.43 seconds)
# Cbc0010I After 13000 nodes, 789 on tree, 0.0084597565 best solution, best possible 0 (480.27 seconds)
# Cbc0010I After 14000 nodes, 780 on tree, 0.0084597565 best solution, best possible 0 (507.42 seconds)
# Cbc0010I After 15000 nodes, 894 on tree, 0.0084597565 best solution, best possible 0 (542.44 seconds)
# Cbc0010I After 16000 nodes, 1012 on tree, 0.0084597565 best solution, best possible 0 (582.90 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 242 rows 256 columns
# Cbc0010I After 17000 nodes, 1106 on tree, 0.0084597565 best solution, best possible 0 (619.58 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 289 rows 326 columns
# Cbc0010I After 18000 nodes, 1265 on tree, 0.0084597565 best solution, best possible 0 (645.85 seconds)
# Cbc0010I After 19000 nodes, 1433 on tree, 0.0084597565 best solution, best possible 0 (682.90 seconds)
# Cbc0010I After 20000 nodes, 1596 on tree, 0.0084597565 best solution, best possible 0 (717.43 seconds)
# Cbc0010I After 21000 nodes, 1645 on tree, 0.0084597565 best solution, best possible 0 (754.63 seconds)
# Cbc0038I Full problem 1050 rows 1453 columns, reduced to 271 rows 299 columns
# Cbc0010I After 22000 nodes, 1650 on tree, 0.0084597565 best solution, best possible 0 (784.84 seconds)
# Cbc0010I After 23000 nodes, 1699 on tree, 0.0084597565 best solution, best possible 0 (825.34 seconds)
# Cbc0010I After 24000 nodes, 1835 on tree, 0.0084597565 best solution, best possible 0 (859.64 seconds)
# Cbc0010I After 25000 nodes, 1942 on tree, 0.0084597565 best solution, best possible 0 (895.32 seconds)
# Cbc003

# %%
def new_date_calculation():
    from datetime import datetime, timedelta
    from datetime import date
    today = datetime.now()
    global out_of_sample_year_start
    global out_of_sample_year_end
    out_of_sample_year_start={}
    out_of_sample_year_end={}
    for year in range(os_years):
        out_of_sample_year_start[(year+1)] = today - timedelta(days=(365 * (os_years - year)))
        two_months_before = out_of_sample_year_start[(year+1)] - timedelta(days=2 * 30)
        out_of_sample_year_start[(year+1)] = two_months_before.replace(day=1)
        years=out_of_sample_year_start[(year+1)].year
        if (years % 4 == 0 and years % 100 != 0) or (years % 400 == 0):
            is_leap_year = True
            no_days_in_year = 366
        else:
            is_leap_year = False
            no_days_in_year = 365
        out_of_sample_year_end[(year+1)]=out_of_sample_year_start[(year+1)]+ timedelta(days=no_days_in_year-1)
        out_of_sample_year_start[(year+1)]=out_of_sample_year_start[(year+1)].strftime("%Y-%m-%d")
        out_of_sample_year_end[(year+1)]=out_of_sample_year_end[(year+1)].strftime("%Y-%m-%d")                        
    
    global in_of_sample_year_start
    in_of_sample_year_start={}
    global in_of_sample_year_end
    in_of_sample_year_end={}
    for year in range(in_years):
        in_of_sample_year_start[(year+1)] = today - timedelta(days=(365 * ((in_years+os_years) - year)))
        two_months_before = in_of_sample_year_start[(year+1)] - timedelta(days=2 * 30)
        in_of_sample_year_start[(year+1)] = two_months_before.replace(day=1)
        years=in_of_sample_year_start[(year+1)].year
        if (years % 4 == 0 and years % 100 != 0) or (years % 400 == 0):
            is_leap_year = True
            no_days_in_year = 366
        else:
            is_leap_year = False
            no_days_in_year = 365
        in_of_sample_year_end[(year+1)]=in_of_sample_year_start[(year+1)]+ timedelta(days=no_days_in_year-1)
        in_of_sample_year_start[(year+1)]=in_of_sample_year_start[(year+1)].strftime("%Y-%m-%d")
        in_of_sample_year_end[(year+1)]=in_of_sample_year_end[(year+1)].strftime("%Y-%m-%d")
    today = date.today()
    formatted_date = today.strftime("%Y-%m-%d")
    today = formatted_date

# %%
def new_run_with_backtest(inyears,outyears):
    
    global os_years
    global in_years
    os_years=outyears
    in_years=inyears
    global performances
    performances={}
    global spy_performances
    spy_performances={}
    new_date_calculation()
    global n_year_before
    global n_year_after
    n_year_before=in_of_sample_year_start[1]
    n_year_after=in_of_sample_year_end[in_years]
    simulator(1,0,0,n_year_before,n_year_after,1000000,50)
    for k in range(os_years): 
        global os_start
        global os_end
        global oos1_new_performances
        oos1_new_performances={}
        global init
        os_start=out_of_sample_year_start[1+k]
        os_end=out_of_sample_year_end[1+k]
        mod_out_of_sample()
        if k == 0:
            performances[k + 1] = oos1_new_performance["Optimized Portfolio"].iloc[-1]
        else:
            performances[k + 1] = oos1_new_performance["Optimized Portfolio"].iloc[-1] * performances[k]
        if k == 0:
            spy_performances[k + 1] = oos1_new_performance["SP_500"].iloc[-1]
        else:
            spy_performances[k + 1] = oos1_new_performance["SP_500"].iloc[-1] * spy_performances[k]

# %%
out_of_sample_year_start
# Out:
# {1: '2019-07-01',
#  2: '2020-07-01',
#  3: '2021-07-01',
#  4: '2022-07-01',
#  5: '2023-07-01'}

# %%
out_of_sample_year_end
# Out:
# {1: '2020-06-29',
#  2: '2021-07-01',
#  3: '2022-06-30',
#  4: '2023-06-30',
#  5: '2024-06-29'}

# %%
oos1_new_performance
# Out:
# Ticker        SP_500  Optimized Portfolio
# Date
# 2023-08-01  1.000000             1.000000
# 2023-09-01  0.982284             0.972485
# 2023-10-01  0.934427             0.942461
# 2023-11-01  0.913889             0.924561
# 2023-12-01  0.995389             1.021270
# 2024-01-01  1.039414             1.089947
# 2024-02-01  1.055936             1.118651
# 2024-03-01  1.110550             1.161966
# 2024-04-01  1.144998             1.182424
# 2024-05-01  1.097349             1.112014
# 2024-06-01  1.150045             1.146598

# %%
spy_performances
# Out:
# {1: 1.0214503446858996,
#  2: 1.3127886825012838,
#  3: 1.2342022805162425,
#  4: 1.2490057031837896,
#  5: 1.4364125753947823}

# %%
performances
# Out:
# {1: 0.9894061797616003,
#  2: 1.3804781110564206,
#  3: 1.305473772996556,
#  4: 1.3351791408672817,
#  5: 1.5309133401415314}

# %%
spy_performances
# Out:
# {1: 1.0214503446858996,
#  2: 1.3127886825012838,
#  3: 1.2342022805162425,
#  4: 1.2490057031837896,
#  5: 1.4364125753947823}

# %%
performances
# Out:
# {1: 0.9473396261718231,
#  2: 1.465623521278164,
#  3: 1.4349326184462579,
#  4: 1.432708998731469,
#  5: 1.5805238018035466}

# %%
new_run_with_backtest(1,5)
# Out:
# [*********************100%%**********************]  501 of 501 completed
#
# 13 Failed downloads:
# ['GEV', 'GEHC', 'SOLV', 'PLTR', 'OTIS', 'CEG', 'KVUE', 'SW', 'CARR', 'ABNB', 'VLTO']: Exception("%ticker%: Data doesn't exist for startDate = 1530417600, endDate = 1561867200")
# ['BF.B']: Exception('%ticker%: No price data found, symbol may be delisted (1mo 2018-07-01 -> 2019-06-30)')
# ['BRK.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  481 of 481 completed
# [**********            20%%                      ]  3 of 15 completed
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l4/hkz5jfdx3t581gbl8x7mfqs40000gn/T/bf099954bda84cecaf2c56ac0b3b17f4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/l4/hkz5jfdx3t581gbl8x7mfqs40000gn/T/bf099954bda84cecaf2c56ac0b3b17f4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 2436 COLUMNS
# At line 20748 RHS
# At line 23180 BOUNDS
# At line 23662 ENDATA
# Problem MODEL has 2431 rows, 2416 columns and 17338 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.02 seconds
# Cgl0004I processed model has 988 rows, 1454 columns (481 integer (481 of which binary)) and 14452 elements
# Cbc0038I Initial state - 12 integers unsatisfied sum - 1
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 0.650758 iterations 514
# Cbc0038I Solution found of 0.650758
# Cbc0038I Relaxing continuous gives 0.650758
# Cbc0038I Before mini branch and bound, 468 integers at bound fixed and 936 continuous
# Cbc0038I Full problem 988 rows 1454 columns, reduced to 37 rows 37 columns
# Cbc0038I Mini branch and bound improved solution from 0.650758 to 0 (0.06 seconds)
# Cbc0038I After 0.06 seconds - Feasibility pump exiting with objective of 0 - took 0.02 seconds
# Cbc0012I Integer solution of 0 found by feasibility pump after 0 iterations and 0 nodes (0.10 seconds)
# Cbc0001I Search completed - best objective 0, took 0 iterations and 0 nodes (0.10 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.23
# Time (Wallclock seconds):       0.24
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.24   (Wallclock seconds):       0.25
# [*********************100%%**********************]  15 of 15 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  15 of 15 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  15 of 15 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  15 of 15 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  15 of 15 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
mod_out_of_sample1()
# Out:
# [*********************100%%**********************]  15 of 15 completed
# [*********************100%%**********************]  1 of 1 completed
# Ticker        SP_500  Optimized Portfolio
# Date
# 2019-08-01  1.000000             1.000000
# 2019-09-01  0.981908             1.007557
# 2019-10-01  0.998779             1.021111
# 2019-11-01  1.019186             1.024908
# 2019-12-01  1.053886             1.048687
# 2020-01-01  1.084016             1.061419
# 2020-02-01  1.082251             1.027290
# 2020-03-01  0.991223             0.933550
# 2020-04-01  0.867202             0.752158
# 2020-05-01  0.977201             0.851776
# 2020-06-01  1.021450             0.947340
# 2020-07-01  1.040233             0.941676
# 2020-08-01  1.097551             0.992344
# 2020-09-01  1.174451             1.041861
# 2020-10-01  1.128380             1.041878
# 2020-11-01  1.097162             1.029082
# 2020-12-01  1.215157             1.155390
# 2021-01-01  1.260266             1.261885
# 2021-02-01  1.246230             1.227325
# 2021-03-01  1.278746             1.315481
# 2021-04-01  1.333015             1.372347
# 2021-05-01  1.402898             1.502205
# 2021-06-01  1.410595             1.535250

# %%
mod_out_of_sample1()
# Out:
# [*********************100%%**********************]  15 of 15 completed
# [*********************100%%**********************]  1 of 1 completed
# Ticker        SP_500  Optimized Portfolio
# Date
# 2019-08-01  1.000000             1.000000
# 2019-09-01  0.981908             1.007557
# 2019-10-01  0.998779             1.021111
# 2019-11-01  1.019186             1.024908
# 2019-12-01  1.053886             1.048687
# 2020-01-01  1.084016             1.061419
# 2020-02-01  1.082251             1.027290
# 2020-03-01  0.991223             0.933550
# 2020-04-01  0.867202             0.752158
# 2020-05-01  0.977201             0.851776
# 2020-06-01  1.021450             0.947340
# 2020-07-01  1.040233             0.941676
# 2020-08-01  1.097551             0.992344
# 2020-09-01  1.174451             1.041861
# 2020-10-01  1.128380             1.041878
# 2020-11-01  1.097162             1.029082
# 2020-12-01  1.215157             1.155390
# 2021-01-01  1.260266             1.261885
# 2021-02-01  1.246230             1.227325
# 2021-03-01  1.278746             1.315481
# 2021-04-01  1.333015             1.372347
# 2021-05-01  1.402898             1.502205
# 2021-06-01  1.410595             1.535250

# %%
oos1_new_performance
# Out:
# Ticker        SP_500  Optimized Portfolio
# Date
# 2022-08-01  1.000000             1.000000
# 2022-09-01  0.957560             0.964121
# 2022-10-01  0.868128             0.874530
# 2022-11-01  0.937460             0.944285
# 2022-12-01  0.987851             0.990464
# 2023-01-01  0.929596             0.928910
# 2023-02-01  0.987001             0.992717
# 2023-03-01  0.961228             0.970294
# 2023-04-01  0.994920             0.997489
# 2023-05-01  1.009488             1.005062
# 2023-06-01  1.011994             1.012111
# 2023-07-01  1.077498             1.079771
# 2023-08-01  1.111050             1.129981
# 2023-09-01  1.091366             1.111190
# 2023-10-01  1.038196             1.061062
# 2023-11-01  1.015377             1.023858
# 2023-12-01  1.105927             1.122516
# 2024-01-01  1.154841             1.183726
# 2024-02-01  1.173198             1.190215
# 2024-03-01  1.233877             1.199922
# 2024-04-01  1.272150             1.229787
# 2024-05-01  1.219210             1.148590
# 2024-06-01  1.277758             1.184656

# %%
print(spy_performances)
# Out:
# {1: 1.011994324513284, 2: 1.1638388601858354}

# %%
print(performances)
# Out:
# {1: 1.059676025966972, 2: 1.1390157060423658}

# %%
def hedge_portfolio_beta(current_beta, target_beta, hedge_ratio, contrat_size, size_of_position, factor_weight, index_futures_price, hedge_period, index_multiple):
    

    if target_beta > current_beta:
        # If target beta is greater, take a long position
        number_of_contracts = (target_beta - current_beta) * (hedge_ratio * (factor_weight * size_of_position) / contrat_size)
        hedge_profit = number_of_contracts * (index_futures_price['Adj Close'].iloc[index_futures_price.index.get_loc(o1_start_d) + hedge_period + 1] - index_futures_price['Adj Close'].iloc[index_futures_price.index.get_loc(o1_start_d) + 1])
        opt_portf_profit = B * (oos1_new_performance.loc[str(index_futures_price.index[index_futures_price.index.get_loc(o1_start_d)+ hedge_period + 1]),'Optimized Portfolio'] - oos1_new_performance.loc[str(index_futures_price.index[index_futures_price.index.get_loc(o1_start_d)+1]),'Optimized Portfolio'])
        total_profit = opt_portf_profit + hedge_profit
        action = "LONG"
    elif target_beta < current_beta:
        # If target beta is smaller, take a short position
        number_of_contracts = (current_beta - target_beta) * (hedge_ratio * size_of_position / contrat_size)
        hedge_profit = number_of_contracts * (index_futures_price['Adj Close'].iloc[index_futures_price.index.get_loc(o1_start_d) + 1] - index_futures_price['Adj Close'].iloc[index_futures_price.index.get_loc(o1_start_d) + hedge_period + 1]) * index_multiple
        opt_portf_profit = B * (oos1_new_performance.loc[str(index_futures_price.index[index_futures_price.index.get_loc(o1_start_d)+ hedge_period + 1]),'Optimized Portfolio'] - oos1_new_performance.loc[str(index_futures_price.index[index_futures_price.index.get_loc(o1_start_d)+1]),'Optimized Portfolio'])
        total_profit = opt_portf_profit + hedge_profit
        action = "SHORT"
    else:
        # If target beta is equal to current beta, no action needed
        action = "no action"
        number_of_contracts = 0
        total_profit = 0

    return action, number_of_contracts, hedge_profit, opt_portf_profit, total_profit, hedge_period

# %%
# o1_start_d + hedge_period + 1
o1_start_d
# Out:
# '2019-07-01'

# %%
end
# Out:
# '2019-06-30'

# %%
round(1/market_hedge_ratio,0)
# Out:
# 4.0

# %%
port_betas
# Out:
#           SP_500  Target  Optimization  Abs. Diff
# Mkt-RF  0.995931       1      0.998588     0.0014
# SMB    -0.185907       0      0.003624     0.0036
# HML    -0.030329       0      0.003607     0.0036

# %%
# MARKET FACTOR - SP_500 FUTURES MINIMUM VARIANCE HEDGE RATIO
sp500_futures = yf.download("ES=F",start=start,end=o1_end_d,interval='1mo')['Adj Close'].pct_change().dropna()
# Fama French Monthly Data using getFamaFrenchFactors module
ff3_monthly = gff.famaFrench3Factor(frequency='m')
ff3_monthly.rename(columns={"date_ff_factors": 'Date'}, inplace=True)
ff3_monthly.set_index('Date', inplace=True)
ff3_monthly.index = ff3_monthly.index.to_period('M').to_timestamp('D')
ff3_monthly = ff3_monthly.loc[sp500_futures[:o1_start_d].index]
# Regression Analysis on Market Factor Vs SP 500 Futures Data 
y = ff3_monthly['Mkt-RF']
X = sp500_futures[:o1_start_d].values.reshape(-1,1)

mkt_model = LinearRegression()
mkt_model.fit(X, y)
market_hedge_ratio = mkt_model.coef_[0]
print('Minimum variance Hedge ratio for Mkt-RF Factor: {:,.2f}'.format(market_hedge_ratio))

# Futures Contract Price for Contract Multiplier
sp500_index_futures_price = yf.download("ES=F",interval='1mo')
sp500_index_futures_price.index = pd.to_datetime(sp500_index_futures_price.index)
sp500_index_futures_price = sp500_index_futures_price.tz_localize(None)
index_multiple = 50

# B is the size of the position
size_of_market_futures_contract = index_multiple * sp500_index_futures_price['Adj Close'].iloc[sp500_index_futures_price.index.get_loc(o1_start_d) + 1]


# mkt_opt is the current beta of Market Factor
mkt_target_beta = 2

# Hedging the Portfolio Using Index Futures
action, number_of_contracts, hedge_profit, opt_portf_profit, total_profit, hedge_period = hedge_portfolio_beta(mkt_opt,mkt_target_beta,market_hedge_ratio, size_of_market_futures_contract, B, 1, sp500_index_futures_price, 4, index_multiple)

print("To change beta from {} to {}, {} {:.0f} contracts over the next {} months and gain/loss from {} futures position is ${:,.2f}\nGain/Loss from optimal portfolio is ${:,.2f}\nTotal Gain/Loss from all of our positions is ${:,.2f}.".format(mkt_opt, mkt_target_beta, action, number_of_contracts, hedge_period, action, hedge_profit, opt_portf_profit, total_profit))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Minimum variance Hedge ratio for Mkt-RF Factor: 1.04
# To change beta from 1 to 2, LONG 7 contracts over the next 4 months and gain/loss from LONG futures position is $186.78
# Gain/Loss from optimal portfolio is $27,290.41
# Total Gain/Loss from all of our positions is $27,477.19.

# %%
# MARKET FACTOR - SP_500 FUTURES MINIMUM VARIANCE HEDGE RATIO
sp500_futures = yf.download("ES=F",start=start,end=o1_end_d,interval='1mo')['Adj Close'].pct_change().dropna()
# Fama French Monthly Data using getFamaFrenchFactors module
ff3_monthly = gff.famaFrench3Factor(frequency='m')
ff3_monthly.rename(columns={"date_ff_factors": 'Date'}, inplace=True)
ff3_monthly.set_index('Date', inplace=True)
ff3_monthly.index = ff3_monthly.index.to_period('M').to_timestamp('D')
ff3_monthly = ff3_monthly.loc[sp500_futures[:o1_start_d].index]
# Regression Analysis on Market Factor Vs SP 500 Futures Data 
y = ff3_monthly['Mkt-RF']
X = sp500_futures[:o1_start_d].values.reshape(-1,1)

mkt_model = LinearRegression()
mkt_model.fit(X, y)
market_hedge_ratio = mkt_model.coef_[0]
print('Minimum variance Hedge ratio for Mkt-RF Factor: {:,.2f}'.format(market_hedge_ratio))

# Futures Contract Price for Contract Multiplier
sp500_index_futures_price = yf.download("ES=F",interval='1mo')
sp500_index_futures_price.index = pd.to_datetime(sp500_index_futures_price.index)
sp500_index_futures_price = sp500_index_futures_price.tz_localize(None)
index_multiple = 50

# B is the size of the position
size_of_market_futures_contract = index_multiple * sp500_index_futures_price['Adj Close'].iloc[sp500_index_futures_price.index.get_loc(o1_start_d) + 1]


# mkt_opt is the current beta of Market Factor
mkt_target_beta = 2

# Hedging the Portfolio Using Index Futures
action, number_of_contracts, hedge_profit, opt_portf_profit, total_profit, hedge_period = hedge_portfolio_beta(mkt_opt,mkt_target_beta,market_hedge_ratio, size_of_market_futures_contract, B, 1, sp500_index_futures_price, 4, index_multiple)

print("To change beta from {} to {}, {} {:.0f} contracts over the next {} months and gain/loss from {} futures position is ${:,.2f}\nGain/Loss from optimal portfolio is ${:,.2f}\nTotal Gain/Loss from all of our positions is ${:,.2f}.".format(mkt_opt, mkt_target_beta, action, number_of_contracts, hedge_period, action, hedge_profit, opt_portf_profit, total_profit))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Minimum variance Hedge ratio for Mkt-RF Factor: 1.04
# To change beta from 1 to 2, LONG 7 contracts over the next 4 months and gain/loss from LONG futures position is $186.78
# Gain/Loss from optimal portfolio is $27,290.41
# Total Gain/Loss from all of our positions is $27,477.19.

# %%
# value FACTOR - SP_500 FUTURES MINIMUM VARIANCE HEDGE RATIO
sp500_futures = yf.download("RTY=F",start=start,end=o1_end_d,interval='1mo')['Adj Close'].pct_change().dropna()
# Fama French Monthly Data using getFamaFrenchFactors module
ff3_monthly = gff.famaFrench3Factor(frequency='m')
ff3_monthly.rename(columns={"date_ff_factors": 'Date'}, inplace=True)
ff3_monthly.set_index('Date', inplace=True)
ff3_monthly.index = ff3_monthly.index.to_period('M').to_timestamp('D')
ff3_monthly = ff3_monthly.loc[sp500_futures[:o1_start_d].index]
# Regression Analysis on Market Factor Vs SP 500 Futures Data 
y = ff3_monthly['SMB']
X = sp500_futures[:o1_start_d].values.reshape(-1,1)

mkt_model = LinearRegression()
mkt_model.fit(X, y)
market_hedge_ratio = mkt_model.coef_[0]
print('Minimum variance Hedge ratio for Mkt-RF Factor: {:,.2f}'.format(market_hedge_ratio))

# Futures Contract Price for Contract Multiplier
sp500_index_futures_price = yf.download("ES=F",interval='1mo')
sp500_index_futures_price.index = pd.to_datetime(sp500_index_futures_price.index)
sp500_index_futures_price = sp500_index_futures_price.tz_localize(None)
index_multiple = 50

# B is the size of the position
size_of_market_futures_contract = index_multiple * sp500_index_futures_price['Adj Close'].iloc[sp500_index_futures_price.index.get_loc(o1_start_d) + 1]


# mkt_opt is the current beta of Market Factor
mkt_target_beta = -0.25

# Hedging the Portfolio Using Index Futures
action, number_of_contracts, hedge_profit, opt_portf_profit, total_profit, hedge_period = hedge_portfolio_beta(-0.24,mkt_target_beta,market_hedge_ratio, size_of_market_futures_contract, B, 4, sp500_index_futures_price, 12, index_multiple)

print("To change beta from {} to {}, {} {:.0f} contracts over the next {} months and gain/loss from {} futures position is ${:,.2f}\nGain/Loss from optimal portfolio is ${:,.2f}\nTotal Gain/Loss from all of our positions is ${:,.2f}.".format(smb_opt, mkt_target_beta, action, number_of_contracts, hedge_period, action, hedge_profit, opt_portf_profit, total_profit))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Minimum variance Hedge ratio for Mkt-RF Factor: 0.24
# [*********************100%%**********************]  1 of 1 completed
# To change beta from 0 to -0.25, SHORT 0 contracts over the next 12 months and gain/loss from SHORT futures position is $-674.74
# Gain/Loss from optimal portfolio is $155,389.59
# Total Gain/Loss from all of our positions is $154,714.86.
#  2575000 nodes, 39261 on tree, 0.0084597565 best solution, best possible 0 (403918.10 seconds)
# Cbc0010I After 2576000 nodes, 39245 on tree, 0.0084597565 best solution, best possible 0 (403956.57 seconds)
# Cbc0010I After 2577000 nodes, 39313 on tree, 0.0084597565 best solution, best possible 0 (403993.97 seconds)
# Cbc0010I After 2578000 nodes, 39313 on tree, 0.0084597565 best solution, best possible 0 (404031.21 seconds)
# Cbc0010I After 2579000 nodes, 39267 on tree, 0.0084597565 best solution, best possible 0 (404069.32 seconds)
# Cbc0010I After 2580000 nodes, 39225 on tree, 0.0084597565 best solution, best possible 0 (404106.71 seconds)
# Cbc0010I After 2581000 nodes, 39244 on tree, 0.0084597565 best solution, best possible 0 (404148.89 seconds)
# Cbc0010I After 2582000 nodes, 39258 on tree, 0.0084597565 best solution, best possible 0 (404191.17 seconds)
# Cbc0010I After 2583000 nodes, 39071 on tree, 0.0084597565 best solution, best possible 0 (404237.72 seconds)
# Cbc0010I After 2584000 nodes, 39030 on tree, 0.0084597565 best solution, best possible 0 (404284.59 seconds)
# Cbc0010I After 2585000 nodes, 38904 on tree, 0.0084597565 best solution, best possible 0 (404331.82 seconds)
# Cbc0010I After 2586000 nodes, 39474 on tree, 0.0084597565 best solution, best possible 0 (404360.66 seconds)
# Cbc0010I After 2587000 nodes, 39490 on tree, 0.0084597565 best solution, best possible 0 (404395.38 seconds)
# Cbc0010I After 2588000 nodes, 39445 on tree, 0.0084597565 best solution, best possible 0 (404436.20 seconds)
# Cbc0010I After 2589000 nodes, 39504 on tree, 0.0084597565 best solution, best possible 0 (404476.24 seconds)
# Cbc0010I After 2590000 nodes, 39414 on tree, 0.0084597565 best solution, best possible 0 (404523.56 seconds)
# Cbc0010I After 2591000 nodes, 39499 on tree, 0.0084597565 best solution, best possible 0 (404560.95 seconds)
# Cbc0010I After 2592000 nodes, 39487 on tree, 0.0084597565 best solution, best possible 0 (404602.42 seconds)
# Cbc0010I After 2593000 nodes, 39482 on tree, 0.0084597565 best solution, best possible 0 (404630.27 seconds)
# Cbc0010I After 2594000 nodes, 39479 on tree, 0.0084597565 best solution, best possible 0 (404668.43 seconds)
# Cbc0010I After 2595000 nodes, 39460 on tree, 0.0084597565 best solution, best possible 0 (404708.36 seconds)
# Cbc0010I After 2596000 nodes, 39504 on tree, 0.0084597565 best solution, best possible 0 (404751.69 seconds)
# Cbc0010I After 2597000 nodes, 39489 on tree, 0.0084597565 best solution, best possible 0 (404798.08 seconds)
# Cbc0010I After 2598000 nodes, 39482 on tree, 0.0084597565 best solution, best possible 0 (404843.28 seconds)
# Cbc0010I After 2599000 nodes, 39429 on tree, 0.0084597565 best solution, best possible 0 (404887.53 seconds)
# Cbc0010I After 2600000 nodes, 39475 on tree, 0.0084597565 best solution, best possible 0 (404932.50 seconds)
# Cbc0010I After 2601000 nodes, 39474 on tree, 0.0084597565 best solution, best possible 0 (404976.79 seconds)
# Cbc0010I After 2602000 nodes, 39453 on tree, 0.0084597565 best solution, best possible 0 (405016.50 seconds)
# Cbc0010I After 2603000 nodes, 39479 on tree, 0.0084597565 best solution, best possible 0 (405058.99 seconds)
# Cbc0010I After 2604000 nodes, 39462 on tree, 0.0084597565 best solution, best possible 0 (405097.96 seconds)
# Cbc0010I After 2605000 nodes, 39416 on tree, 0.0084597565 best solution, best possible 0 (405135.92 seconds)
# Cbc0010I After 2606000 nodes, 39523 on tree, 0.0084597565 best solution, best possible 0 (405174.43 seconds)
# Cbc0010I After 2607000 nodes, 39479 on tree, 0.0084597565 best solution, best possible 0 (405218.70 seconds)
# Cbc0010I After 2608000 nodes, 39458 on tree, 0.0084597565 best solution, best possible 0 (405263.11 seconds)
# Cbc0010I After 2609000 nodes, 39483 on tree, 0.0084597565 best solution, best possible 0 (405309.73 seconds)
# Cbc0010I After 2610000 nodes, 39493 on tree, 0.0084597565 best solution, best possible 0 (405356.13 seconds)
# Cbc0010I After 2611000 nodes, 39459 on tree, 0.0084597565 best solution, best possible 0 (405403.32 seconds)
# Cbc0010I After 2612000 nodes, 39458 on tree, 0.0084597565 best solution, best possible 0 (405445.93 seconds)
# Cbc0010I After 2613000 nodes, 39497 on tree, 0.0084597565 best solution, best possible 0 (405490.67 seconds)
# Cbc0010I After 2614000 nodes, 39477 on tree, 0.0084597565 best solution, best possible 0 (405536.67 seconds)
# Cbc0010I After 2615000 nodes, 39422 on tree, 0.0084597565 best solution, best possible 0 (405579.72 seconds)
# Cbc0010I After 2616000 nodes, 39521 on tree, 0.0084597565 best solution, best possible 0 (405619.40 seconds)
# Cbc0010I After 2617000 nodes, 39529 on tree, 0.0084597565 best solution, best possible 0 (405656.91 seconds)
# Cbc0010I After 2618000 nodes, 39445 on tree, 0.0084597565 best solution, best possible 0 (405696.96 seconds)
# Cbc0010I After 2619000 nodes, 39512 on tree, 0.0084597565 best solution, best possible 0 (405741.02 seconds)
# Cbc0010I After 2620000 nodes, 39492 on tree, 0.0084597565 best solution, best possible 0 (405787.46 seconds)
# Cbc0010I After 2621000 nodes, 39497 on tree, 0.0084597565 best solution, best possible 0 (405843.59 seconds)
# Cbc0010I After 2622000 nodes, 39499 on tree, 0.0084597565 best solution, best possible 0 (405890.03 seconds)
# Cbc0010I After 2623000 nodes, 39486 on tree, 0.0084597565 best solution, best possible 0 (405935.44 seconds)
# Cbc0010I After 2624000 nodes, 39499 on tree, 0.0084597565 best solution, best possible 0 (405972.96 seconds)
# Cbc0010I After 2625000 nodes, 39502 on tree, 0.0084597565 best solution, best possible 0 (406011.57 seconds)
# Cbc0010I After 2626000 nodes, 39473 on tree, 0.0084597565 best solution, best possible 0 (406050.93 seconds)
# Cbc0010I After 2627000 nodes, 39493 on tree, 0.0084597565 best solution, best possible 0 (406092.05 seconds)
# Cbc0010I After 2628000 nodes, 39513 on tree, 0.0084597565 best solution, best possible 0 (406134.06 seconds)
# Cbc0010I After 2629000 nodes, 39484 on tree, 0.0084597565 best solution, best possible 0 (406177.98 seconds)
# Cbc0010I After 2630000 nodes, 39505 on tree, 0.0084597565 best solution, best possible 0 (406222.79 seconds)
# Cbc0010I After 2631000 nodes, 39495 on tree, 0.0084597565 best solution, best possible 0 (406269.54 seconds)
# Cbc0010I After 2632000 nodes, 39505 on tree, 0.0084597565 best solution, best possible 0 (406317.76 seconds)
# Cbc0010I After 2633000 nodes, 39525 on tree, 0.0084597565 best solution, best possible 0 (406364.05 seconds)
# Cbc0010I After 2634000 nodes, 39472 on tree, 0.0084597565 best solution, best possible 0 (406409.46 seconds)
# Cbc0010I After 2635000 nodes, 39459 on tree, 0.0084597565 best solution, best possible 0 (406455.78 seconds)
# Cbc0010I After 2636000 nodes, 39476 on tree, 0.0084597565 best solution, best possible 0 (406498.34 seconds)
# Cbc0010I After 2637000 nodes, 39474 on tree, 0.0084597565 best solution, best possible 0 (406535.96 seconds)
# Cbc0010I After 2638000 nodes, 39429 on tree, 0.0084597565 best solution, best possible 0 (406577.14 seconds)
# Cbc0010I After 2639000 nodes, 39501 on tree, 0.0084597565 best solution, best possible 0 (406608.53 seconds)
# Cbc0010I After 2640000 nodes, 39517 on tree, 0.0084597565 best solution, best possible 0 (406641.76 seconds)
# Cbc0010I After 2641000 nodes, 39489 on tree, 0.0084597565 best solution, best possible 0 (406678.54 seconds)
# Cbc0010I After 2642000 nodes, 39453 on tree, 0.0084597565 best solution, best possible 0 (406718.23 seconds)
# Cbc0010I After 2643000 nodes, 39511 on tree, 0.0084597565 best solution, best possible 0 (406759.12 seconds)
# Cbc0010I After 2644000 nodes, 39506 on tree, 0.0084597565 best solution, best possible 0 (406799.53 seconds)
# Cbc0010I After 2645000 nodes, 39461 on tree, 0.0084597565 best solution, best possible 0 (406842.60 seconds)
# Cbc0010I After 2646000 nodes, 39511 on tree, 0.0084597565 best solution, best possible 0 (406885.76 seconds)
# Cbc0010I After 2647000 nodes, 39446 on tree, 0.0084597565 best solution, best possible 0 (406929.33 seconds)
# Cbc0010I After 2648000 nodes, 39510 on tree, 0.0084597565 best solution, best possible 0 (406974.08 seconds)
# Cbc0010I After 2649000 nodes, 39473 on tree, 0.0084597565 best solution, best possible 0 (407035.52 seconds)
# Cbc0010I After 2650000 nodes, 39523 on tree, 0.0084597565 best solution, best possible 0 (407080.11 seconds)
# Cbc0010I After 2651000 nodes, 39476 on tree, 0.0084597565 best solution, best possible 0 (407125.15 seconds)
# Cbc0010I After 2652000 nodes, 39523 on tree, 0.0084597565 best solution, best possible 0 (407171.40 seconds)
# Cbc0010I After 2653000 nodes, 39480 on tree, 0.0084597565 best solution, best possible 0 (407217.98 seconds)
# Cbc0010I After 2654000 nodes, 39484 on tree, 0.0084597565 best solution, best possible 0 (407254.35 seconds)
# Cbc0010I After 2655000 nodes, 39518 on tree, 0.0084597565 best solution, best possible 0 (407295.98 seconds)
# Cbc0010I After 2656000 nodes, 39468 on tree, 0.0084597565 best solution, best possible 0 (407345.61 seconds)
# Cbc0010I After 2657000 nodes, 39509 on tree, 0.0084597565 best solution, best possible 0 (407368.62 seconds)
# Cbc0010I After 2658000 nodes, 39522 on tree, 0.0084597565 best solution, best possible 0 (407395.67 seconds)
# Cbc0010I After 2659000 nodes, 39524 on tree, 0.0084597565 best solution, best possible 0 (407432.23 seconds)
# Cbc0010I After 2660000 nodes, 39472 on tree, 0.0084597565 best solution, best possible 0 (407466.39 seconds)
# Cbc0010I After 2661000 nodes, 39522 on tree, 0.0084597565 best solution, best possible 0 (407500.51 seconds)
# Cbc0010I After 2662000 nodes, 39475 on tree, 0.0084597565 best solution, best possible 0 (407536.71 seconds)
# Cbc0010I After 2663000 nodes, 39462 on tree, 0.0084597565 best solution, best possible 0 (407574.48 seconds)
# Cbc0010I After 2664000 nodes, 39535 on tree, 0.0084597565 best solution, best possible 0 (407612.02 seconds)
# Cbc0010I After 2665000 nodes, 39519 on tree, 0.0084597565 best solution, best possible 0 (407647.81 seconds)
# Cbc0010I After 2666000 nodes, 39451 on tree, 0.0084597565 best solution, best possible 0 (407682.18 seconds)
# Cbc0010I After 2667000 nodes, 39545 on tree, 0.0084597565 best solution, best possible 0 (407721.53 seconds)
# Cbc0010I After 2668000 nodes, 39453 on tree, 0.0084597565 best solution, best possible 0 (407757.77 seconds)
# Cbc0010I After 2669000 nodes, 39513 on tree, 0.0084597565 best solution, best possible 0 (407794.09 seconds)
# Cbc0010I After 2670000 nodes, 39447 on tree, 0.0084597565 best solution, best possible 0 (407834.96 seconds)
# Cbc0010I After 2671000 nodes, 39441 on tree, 0.0084597565 best solution, best possible 0 (407876.31 seconds)
# Cbc0010I After 2672000 nodes, 39515 on tree, 0.0084597565 best solution, best possible 0 (407923.47 seconds)
# Cbc0010I After 2673000 nodes, 39508 on tree, 0.0084597565 best solution, best possible 0 (407975.71 seconds)
# Cbc0010I After 2674000 nodes, 39509 on tree, 0.0084597565 best solution, best possible 0 (408041.81 seconds)
# Cbc0010I After 2675000 nodes, 39483 on tree, 0.0084597565 best solution, best possible 0 (408103.38 seconds)
# Cbc0010I After 2676000 nodes, 39508 on tree, 0.0084597565 best solution, best possible 0 (408138.85 seconds)
# Cbc0010I After 2677000 nodes, 39478 on tree, 0.0084597565 best solution, best possible 0 (408181.09 seconds)
# Cbc0010I After 2678000 nodes, 39497 on tree, 0.0084597565 best solution, best possible 0 (408227.45 seconds)
# Cbc0010I After 2679000 nodes, 39462 on tree, 0.0084597565 best solution, best possible 0 (408277.44 seconds)
# Cbc0010I After 2680000 nodes, 39481 on tree, 0.0084597565 best solution, best possible 0 (408330.36 seconds)
# Cbc0010I After 2681000 nodes, 39443 on tree, 0.0084597565 best solution, best possible 0 (408385.53 seconds)
# Cbc0010I After 2682000 nodes, 39509 on tree, 0.0084597565 best solution, best possible 0 (408439.40 seconds)
# Cbc0010I After 2683000 nodes, 39507 on tree, 0.0084597565 best solution, best possible 0 (408494.93 seconds)
# Cbc0010I After 2684000 nodes, 39425 on tree, 0.0084597565 best solution, best possible 0 (408548.17 seconds)
# Cbc0010I After 2685000 nodes, 39466 on tree, 0.0084597565 best solution, best possible 0 (408603.37 seconds)
# Cbc0010I After 2686000 nodes, 39503 on tree, 0.0084597565 best solution, best possible 0 (408637.40 seconds)
# Cbc0010I After 2687000 nodes, 39485 on tree, 0.0084597565 best solution, best possible 0 (408676.70 seconds)
# Cbc0010I After 2688000 nodes, 39490 on tree, 0.0084597565 best solution, best possible 0 (408719.92 seconds)
# Cbc0010I After 2689000 nodes, 39465 on tree, 0.0084597565 best solution, best possible 0 (408768.25 seconds)
# Cbc0010I After 2690000 nodes, 39466 on tree, 0.0084597565 best solution, best possible 0 (408819.64 seconds)
# Cbc0010I After 2691000 nodes, 39466 on tree, 0.0084597565 best solution, best possible 0 (408873.73 seconds)
# Cbc0010I After 2692000 nodes, 39509 on tree, 0.0084597565 best solution, best possible 0 (408922.55 seconds)
# Cbc0010I After 2693000 nodes, 39449 on tree, 0.0084597565 best solution, best possible 0 (408969.86 seconds)
# Cbc0010I After 2694000 nodes, 39432 on tree, 0.0084597565 best solution, best possible 0 (409016.99 seconds)
# Cbc0010I After 2695000 nodes, 39425 on tree, 0.0084597565 best solution, best possible 0 (409066.67 seconds)
# Cbc0010I After 2696000 nodes, 39428 on tree, 0.0084597565 best solution, best possible 0 (409115.05 seconds)
# Cbc0010I After 2697000 nodes, 39533 on tree, 0.0084597565 best solution, best possible 0 (409158.74 seconds)
# Cbc0010I After 2698000 nodes, 39479 on tree, 0.0084597565 best solution, best possible 0 (409213.72 seconds)
# Cbc0010I After 2699000 nodes, 39495 on tree, 0.0084597565 best solution, best possible 0 (409273.16 seconds)
# Cbc0010I After 2700000 nodes, 39473 on tree, 0.0084597565 best solution, best possible 0 (409328.23 seconds)
# Cbc0010I After 2701000 nodes, 39506 on tree, 0.0084597565 best solution, best possible 0 (409362.67 seconds)
# Cbc0010I After 2702000 nodes, 39509 on tree, 0.0084597565 best solution, best possible 0 (409393.29 seconds)
# Cbc0010I After 2703000 nodes, 39506 on tree, 0.0084597565 best solution, best possible 0 (409434.98 seconds)
# Cbc0010I After 2704000 nodes, 39487 on tree, 0.0084597565 best solution, best possible 0 (409477.51 seconds)
# Cbc0010I After 2705000 nodes, 39504 on tree, 0.0084597565 best solution, best possible 0 (409524.60 seconds)
# Cbc0010I After 2706000 nodes, 39496 on tree, 0.0084597565 best solution, best possible 0 (409572.15 seconds)
# Cbc0010I After 2707000 nodes, 39496 on tree, 0.0084597565 best solution, best possible 0 (409619.63 seconds)
# Cbc0010I After 2708000 nodes, 39494 on tree, 0.0084597565 best solution, best possible 0 (409669.73 seconds)
# Cbc0010I After 2709000 nodes, 39434 on tree, 0.0084597565 best solution, best possible 0 (409723.33 seconds)
# Cbc0010I After 2710000 nodes, 39486 on tree, 0.0084597565 best solution, best possible 0 (409779.21 seconds)
# Cbc0010I After 2711000 nodes, 39462 on tree, 0.0084597565 best solution, best possible 0 (409832.98 seconds)
# Cbc0010I After 2712000 nodes, 39423 on tree, 0.0084597565 best solution, best possible 0 (409882.71 seconds)
# Cbc0010I After 2713000 nodes, 39511 on tree, 0.0084597565 best solution, best possible 0 (409932.47 seconds)
# Cbc0010I After 2714000 nodes, 39508 on tree, 0.0084597565 best solution, best possible 0 (409982.58 seconds)
# Cbc0010I After 2715000 nodes, 39358 on tree, 0.0084597565 best solution, best possible 0 (410053.49 seconds)
# Cbc0010I After 2716000 nodes, 39261 on tree, 0.0084597565 best solution, best possible 0 (410121.15 seconds)
# Cbc0010I After 2717000 nodes, 39218 on tree, 0.0084597565 best solution, best possible 0 (410192.45 seconds)
# Cbc0010I After 2718000 nodes, 39263 on tree, 0.0084597565 best solution, best possible 0 (410238.52 seconds)
# Cbc0010I After 2719000 nodes, 39272 on tree, 0.0084597565 best solution, best possible 0 (410285.39 seconds)
# Cbc0010I After 2720000 nodes, 39254 on tree, 0.0084597565 best solution, best possible 0 (410334.20 seconds)
# Cbc0010I After 2721000 nodes, 39225 on tree, 0.0084597565 best solution, best possible 0 (410379.86 seconds)
# Cbc0010I After 2722000 nodes, 39237 on tree, 0.0084597565 best solution, best possible 0 (410419.23 seconds)
# Cbc0010I After 2723000 nodes, 39212 on tree, 0.0084597565 best solution, best possible 0 (410461.76 seconds)
# Cbc0010I After 2724000 nodes, 39246 on tree, 0.0084597565 best solution, best possible 0 (410509.81 seconds)
# Cbc0010I After 2725000 nodes, 39208 on tree, 0.0

# %%
sp500_index_futures_price[]
# Out:
#                Open     High      Low   Close  Adj Close    Volume
# Date
# 2000-11-01  1441.00  1455.00  1296.75  1321.0     1321.0   1909980
# 2000-12-01  1321.50  1392.00  1270.25  1327.0     1327.0   1176792
# 2001-01-01  1331.00  1394.00  1287.50  1373.5     1373.5   2260093
# 2001-02-01  1373.50  1386.00  1217.00  1242.0     1242.0   2313400
# 2001-03-01  1239.25  1270.50  1088.00  1174.0     1174.0   2324363
# ...             ...      ...      ...     ...        ...       ...
# 2024-05-01  5050.00  5368.25  5036.25  5295.5     5295.5  29665464
# 2024-06-01  5299.50  5585.00  5246.75  5521.5     5521.5  26941704
# 2024-07-01  5534.25  5721.25  5432.50  5558.0     5558.0  37581209
# 2024-08-01  5574.75  5669.00  5120.00  5661.0     5661.0  36160490
# 2024-10-01  5760.25  5763.50  5742.50  5746.5     5746.5     15868
#
# [247 rows x 6 columns]

# %%
ff3_monthly
# Out:
#             Mkt-RF     SMB     HML      RF
# Date
# 2018-09-01  0.0006 -0.0229 -0.0171  0.0015
# 2018-10-01 -0.0768 -0.0474  0.0340  0.0019
# 2018-11-01  0.0169 -0.0068  0.0028  0.0018
# 2018-12-01 -0.0957 -0.0237 -0.0188  0.0020
# 2019-01-01  0.0840  0.0288 -0.0045  0.0021
# 2019-02-01  0.0340  0.0206 -0.0271  0.0018
# 2019-03-01  0.0110 -0.0305 -0.0412  0.0019
# 2019-04-01  0.0397 -0.0172  0.0216  0.0021
# 2019-05-01 -0.0694 -0.0131 -0.0237  0.0021
# 2019-06-01  0.0693  0.0028 -0.0070  0.0018
# 2019-07-01  0.0119 -0.0193  0.0047  0.0019

# %%
o1_end_d
# Out:
# '2021-07-01'

# %%
sp500_futures
# Out:
# Date
# 2018-09-01    0.005858
# 2018-10-01   -0.071257
# 2018-11-01    0.017429
# 2018-12-01   -0.091725
# 2019-01-01    0.079533
# 2019-02-01    0.029673
# 2019-03-01    0.019032
# 2019-04-01    0.039027
# 2019-05-01   -0.066474
# 2019-06-01    0.069664
# 2019-07-01    0.012907
# 2019-08-01   -0.019281
# 2019-10-01    0.037952
# 2019-11-01    0.035576
# 2020-01-01    0.025527
# 2020-02-01   -0.084677
# 2020-04-01   -0.016435
# 2020-05-01    0.048062
# 2020-06-01    0.015861
# 2020-07-01    0.056063
# 2020-08-01    0.072162
# 2020-09-01   -0.042012
# 2020-10-01   -0.026029
# 2020-12-01    0.148250
# 2021-01-01   -0.011604
# 2021-02-01    0.028068
# 2021-03-01    0.041544
# 2021-04-01    0.052174
# 2021-05-01    0.006707
# 2021-06-01    0.020464
# Name: Adj Close, dtype: float64

# %%
smb_opt
# Out:
# 0

# %%
size_of_market_futures_contract
# Out:
# 146237.5

# %%
ff3_monthly
# Out:
#             Mkt-RF     SMB     HML      RF
# Date
# 2018-09-01  0.0006 -0.0229 -0.0171  0.0015
# 2018-10-01 -0.0768 -0.0474  0.0340  0.0019
# 2018-11-01  0.0169 -0.0068  0.0028  0.0018
# 2018-12-01 -0.0957 -0.0237 -0.0188  0.0020
# 2019-01-01  0.0840  0.0288 -0.0045  0.0021
# 2019-02-01  0.0340  0.0206 -0.0271  0.0018
# 2019-03-01  0.0110 -0.0305 -0.0412  0.0019
# 2019-04-01  0.0397 -0.0172  0.0216  0.0021
# 2019-05-01 -0.0694 -0.0131 -0.0237  0.0021
# 2019-06-01  0.0693  0.0028 -0.0070  0.0018
# 2019-07-01  0.0119 -0.0193  0.0047  0.0019

# %%
hml_opt
# Out:
# 0

# %%
new_run_with_backtest(3,2)
# Out:
# [*********************100%%**********************]  501 of 501 completed
#
# 8 Failed downloads:
# ['GEV', 'SOLV', 'GEHC', 'KVUE', 'SW', 'VLTO']: Exception("%ticker%: Data doesn't exist for startDate = 1561953600, endDate = 1656561600")
# ['BF.B']: Exception('%ticker%: No price data found, symbol may be delisted (1mo 2019-07-01 -> 2022-06-30)')
# ['BRK.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  488 of 488 completed
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l4/hkz5jfdx3t581gbl8x7mfqs40000gn/T/39dc76604e314e93819ef0db9aea81f3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/l4/hkz5jfdx3t581gbl8x7mfqs40000gn/T/39dc76604e314e93819ef0db9aea81f3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 2519 COLUMNS
# At line 44587 RHS
# At line 47102 BOUNDS
# At line 47591 ENDATA
# Problem MODEL has 2514 rows, 2475 columns and 41056 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.06 seconds
# Cgl0004I processed model has 1050 rows, 1499 columns (488 integer (488 of which binary)) and 38128 elements
# Cbc0038I Initial state - 36 integers unsatisfied sum - 1
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 3.12267 iterations 674
# Cbc0038I Solution found of 3.12267
# Cbc0038I Relaxing continuous gives 3.12267
# Cbc0038I Before mini branch and bound, 451 integers at bound fixed and 901 continuous
# Cbc0038I Full problem 1050 rows 1499 columns, reduced to 110 rows 109 columns
# Cbc0038I Mini branch and bound improved solution from 3.12267 to 0 (0.21 seconds)
# Cbc0038I After 0.21 seconds - Feasibility pump exiting with objective of 0 - took 0.07 seconds
# Cbc0012I Integer solution of 0 found by feasibility pump after 0 iterations and 0 nodes (0.30 seconds)
# Cbc0001I Search completed - best objective 0, took 0 iterations and 0 nodes (0.30 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.59
# Time (Wallclock seconds):       0.65
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.61   (Wallclock seconds):       0.68
# [*********************100%%**********************]  36 of 36 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  36 of 36 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
performances
# Out:
# {1: 1.059676025966972, 2: 1.1390157060423658}

# %%
spy_performances
# Out:
# {1: 1.011994324513284, 2: 1.1638388601858354}

# %%
new_date_calculation()

# %%
def variable_current_date():
    global today
    global os_start
    global os_end
    global n_year_before
    global n_year_after
    os_years

# %%
simulator(1.1,0,0.25,'2020-03-01','2023-01-01',1000000,50) 
port_betas
out_of_sample()
# Out:
# [*********************100%%**********************]  501 of 501 completed
#
# 8 Failed downloads:
# ['SW', 'GEV', 'VLTO', 'KVUE', 'SOLV']: Exception("%ticker%: Data doesn't exist for startDate = 1583038800, endDate = 1672549200")
# ['GEHC']: IndexError('index 0 is out of bounds for axis 0 with size 0')
# ['BRK.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ['BF.B']: Exception('%ticker%: No price data found, symbol may be delisted (1mo 2020-03-01 -> 2023-01-01)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  489 of 489 completed
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l4/hkz5jfdx3t581gbl8x7mfqs40000gn/T/d7f78e8060f346a0883f7aa4dfd4f58b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/l4/hkz5jfdx3t581gbl8x7mfqs40000gn/T/d7f78e8060f346a0883f7aa4dfd4f58b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 2520 COLUMNS
# At line 42712 RHS
# At line 45228 BOUNDS
# At line 45718 ENDATA
# Problem MODEL has 2515 rows, 2478 columns and 39180 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.06 seconds
# Cgl0004I processed model has 1048 rows, 1500 columns (489 integer (489 of which binary)) and 36246 elements
# Cbc0038I Initial state - 34 integers unsatisfied sum - 1
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 1.04029 iterations 660
# Cbc0038I Solution found of 1.04029
# Cbc0038I Relaxing continuous gives 1.04029
# Cbc0038I Before mini branch and bound, 454 integers at bound fixed and 908 continuous
# Cbc0038I Full problem 1048 rows 1500 columns, reduced to 104 rows 103 columns
# Cbc0038I Mini branch and bound improved solution from 1.04029 to 0 (0.18 seconds)
# Cbc0038I After 0.18 seconds - Feasibility pump exiting with objective of 0 - took 0.07 seconds
# Cbc0012I Integer solution of 0 found by feasibility pump after 0 iterations and 0 nodes (0.27 seconds)
# Cbc0001I Search completed - best objective 0, took 0 iterations and 0 nodes (0.28 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.61
# Time (Wallclock seconds):       0.66
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.62   (Wallclock seconds):       0.68
# [*********************100%%**********************]  34 of 34 completed
# [*********************100%%**********************]  1 of 1 completed
# Ticker        SP_500  Optimized Portfolio
# Date
# 2023-07-01  1.000000             1.000000
# 2023-08-01  1.031139             1.060492
# 2023-09-01  1.012871             1.042470
# 2023-10-01  0.963524             0.995064
# 2023-11-01  0.942346             0.946859
# 2023-12-01  1.026384             1.051127
# 2024-01-01  1.071780             1.115057
# 2024-02-01  1.088817             1.098178
# 2024-03-01  1.145131             1.116141
# 2024-04-01  1.180652             1.147582
# 2024-05-01  1.131519             1.085882
# 2024-06-01  1.185856             1.119621

# %%
def visual():
      plt.style.use('ggplot')
      fig = plt.figure(figsize=(12,8), dpi=100)
      axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])   # left, bottom, width, height (range 0 to 1)
      for i in range(0,len(oos1_daily_data.columns[-2:])):
        axes.plot(oos1_new_performance.index, oos1_new_performance.iloc[:,i], linewidth=1)
      axes.set_xlabel('Date')
      axes.set_ylabel('Performance')
      axes.set_title('Out of Sample 1 - Daily Performance of $1 USD of Portfolios')
      axes.legend(oos1_daily_data.columns[-2:], bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0, fontsize='small')
      plt.savefig('oos1_daily_performance.png') 
      plt.show()

# %%
def random_generate_beta(l,u):
    upper_limit=u
    lower_limit=l
    random_number=round(random.uniform(lower_limit, upper_limit), 2)
    return random_number

# %%
testing_beta_mkt=random_generate_beta(1,1.2)
testing_beta_val=random_generate_beta(0,0)
testing_beta_smb=random_generate_beta(0,0)
print(testing_beta_mkt, testing_beta_val,testing_beta_smb)
def run_with_backtestss(nyears):
    
    global n_years
    n_years=nyears
    current_date()
    simulator(testing_beta_mkt,testing_beta_val,testing_beta_smb,n_year_before,n_year_after,1000000,50) 
    out_of_sample()
  
    return oos1_new_performance

run_with_backtestss(3)
# Out:
# 1.02 0.0 0.0
# [*********************100%%**********************]  501 of 501 completed
#
# 6 Failed downloads:
# ['GEV', 'SOLV', 'SW', 'VLTO']: Exception("%ticker%: Data doesn't exist for startDate = 1593576000, endDate = 1688184000")
# ['BF.B']: Exception('%ticker%: No price data found, symbol may be delisted (1mo 2020-07-01 -> 2023-07-01)')
# ['BRK.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  490 of 490 completed
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l4/hkz5jfdx3t581gbl8x7mfqs40000gn/T/645f92fe1ba44eabb5b5b0aad85fc6e5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/l4/hkz5jfdx3t581gbl8x7mfqs40000gn/T/645f92fe1ba44eabb5b5b0aad85fc6e5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 2529 COLUMNS
# At line 44769 RHS
# At line 47294 BOUNDS
# At line 47785 ENDATA
# Problem MODEL has 2524 rows, 2485 columns and 41224 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.06 seconds
# Cgl0004I processed model has 1054 rows, 1505 columns (490 integer (490 of which binary)) and 38284 elements
# Cbc0038I Initial state - 36 integers unsatisfied sum - 1
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 2.17193 iterations 657
# Cbc0038I Solution found of 2.17193
# Cbc0038I Relaxing continuous gives 2.17193
# Cbc0038I Before mini branch and bound, 453 integers at bound fixed and 906 continuous
# Cbc0038I Full problem 1054 rows 1505 columns, reduced to 110 rows 109 columns
# Cbc0038I Mini branch and bound improved solution from 2.17193 to 0 (0.19 seconds)
# Cbc0038I After 0.19 seconds - Feasibility pump exiting with objective of 0 - took 0.07 seconds
# Cbc0012I Integer solution of 0 found by feasibility pump after 0 iterations and 0 nodes (0.28 seconds)
# Cbc0001I Search completed - best objective 0, took 0 iterations and 0 nodes (0.28 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.54
# Time (Wallclock seconds):       0.59
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.56   (Wallclock seconds):       0.61
# [*********************100%%**********************]  36 of 36 completed
# [*********************100%%**********************]  1 of 1 completed
# Ticker        SP_500  Optimized Portfolio
# Date
# 2023-08-01  1.000000             1.000000
# 2023-09-01  0.982284             0.982084
# 2023-10-01  0.934427             0.935691
# 2023-11-01  0.913889             0.906989
# 2023-12-01  0.995389             0.991257
# 2024-01-01  1.039414             1.042958
# 2024-02-01  1.055936             1.045114
# 2024-03-01  1.110550             1.046608
# 2024-04-01  1.144998             1.074531
# 2024-05-01  1.097349             1.005968
# 2024-06-01  1.150045             1.041978
# 2024-07-01  1.189917             1.078164

# %%
sharess.to_excel('shares2.xlsx')

# %%
visual()
ff3_monthly.corr()
# Out:
#           Mkt-RF       SMB       HML        RF
# Mkt-RF  1.000000  0.181224 -0.174750  0.026484
# SMB     0.181224  1.000000 -0.131086 -0.056534
# HML    -0.174750 -0.131086  1.000000 -0.336262
# RF      0.026484 -0.056534 -0.336262  1.000000

# %%
port_betas
# Out:
#           SP_500  Target  Optimization  Abs. Diff
# Mkt-RF  0.990583    1.16      1.159537     0.0005
# SMB    -0.190665    0.00     -0.004695     0.0047
# HML     0.005874    0.19      0.179655     0.0103

# %%
simulator(1,0,0,'2020-03-01','2023-01-01',1000000,50) 
port_betas
out_of_sample()
# Out:
# [*********************100%%**********************]  501 of 501 completed
#
# 7 Failed downloads:
# ['BF.B']: Exception('%ticker%: No price data found, symbol may be delisted (1mo 2020-03-01 -> 2023-01-01)')
# ['GEV', 'SOLV', 'KVUE', 'VLTO']: Exception("%ticker%: Data doesn't exist for startDate = 1583038800, endDate = 1672549200")
# ['BRK.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ['GEHC']: IndexError('index 0 is out of bounds for axis 0 with size 0')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  490 of 490 completed
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l4/hkz5jfdx3t581gbl8x7mfqs40000gn/T/47a56c3f37a94d3c946f06441f10e449-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/l4/hkz5jfdx3t581gbl8x7mfqs40000gn/T/47a56c3f37a94d3c946f06441f10e449-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 2525 COLUMNS
# At line 42797 RHS
# At line 45318 BOUNDS
# At line 45809 ENDATA
# Problem MODEL has 2520 rows, 2483 columns and 39258 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.06 seconds
# Cgl0004I processed model has 1050 rows, 1503 columns (490 integer (490 of which binary)) and 36318 elements
# Cbc0038I Initial state - 34 integers unsatisfied sum - 1
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 1.73589 iterations 635
# Cbc0038I Solution found of 1.73589
# Cbc0038I Relaxing continuous gives 1.73589
# Cbc0038I Before mini branch and bound, 455 integers at bound fixed and 910 continuous
# Cbc0038I Full problem 1050 rows 1503 columns, reduced to 104 rows 103 columns
# Cbc0038I Mini branch and bound improved solution from 1.73589 to 0 (0.17 seconds)
# Cbc0038I After 0.18 seconds - Feasibility pump exiting with objective of 0 - took 0.06 seconds
# Cbc0012I Integer solution of 0 found by feasibility pump after 0 iterations and 0 nodes (0.25 seconds)
# Cbc0001I Search completed - best objective 0, took 0 iterations and 0 nodes (0.26 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.51
# Time (Wallclock seconds):       0.54
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.52   (Wallclock seconds):       0.56
# [*********************100%%**********************]  34 of 34 completed
# [*********************100%%**********************]  1 of 1 completed
# Ticker        SP_500  Optimized Portfolio
# Date
# 2023-03-01  1.000000             1.000000
# 2023-04-01  1.035052             1.037034
# 2023-05-01  1.050207             1.032959
# 2023-06-01  1.052814             1.018456
# 2023-07-01  1.120960             1.087384
# 2023-08-01  1.155866             1.109311
# 2023-09-01  1.135388             1.078588
# 2023-10-01  1.080073             1.017738
# 2023-11-01  1.056333             0.970299
# 2023-12-01  1.150536             1.063842
# 2024-01-01  1.201423             1.131781
# 2024-02-01  1.220521             1.126440

# %%
simulator(1,0,0,'2020-02-01','2023-01-01',1000000,50) 
port_betas
out_of_sample()
# Out:
# [*********************100%%**********************]  501 of 501 completed
#
# 6 Failed downloads:
# ['VLTO', 'KVUE', 'SOLV', 'GEV']: Exception("%ticker%: Data doesn't exist for startDate = 1580533200, endDate = 1672549200")
# ['BRK.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ['BF.B']: Exception('%ticker%: No price data found, symbol may be delisted (1mo 2020-02-01 -> 2023-01-01)')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  490 of 490 completed
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l4/hkz5jfdx3t581gbl8x7mfqs40000gn/T/c22237c3835e4600ac8c8c3bf2cd055d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/l4/hkz5jfdx3t581gbl8x7mfqs40000gn/T/c22237c3835e4600ac8c8c3bf2cd055d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 2527 COLUMNS
# At line 43784 RHS
# At line 46307 BOUNDS
# At line 46798 ENDATA
# Problem MODEL has 2522 rows, 2484 columns and 40242 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.05 seconds
# Cgl0004I processed model has 1052 rows, 1504 columns (490 integer (490 of which binary)) and 37302 elements
# Cbc0038I Initial state - 34 integers unsatisfied sum - 1
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 2.1138 iterations 644
# Cbc0038I Solution found of 2.1138
# Cbc0038I Relaxing continuous gives 2.1138
# Cbc0038I Before mini branch and bound, 454 integers at bound fixed and 908 continuous
# Cbc0038I Full problem 1052 rows 1504 columns, reduced to 107 rows 106 columns
# Cbc0038I Mini branch and bound improved solution from 2.1138 to 0 (0.17 seconds)
# Cbc0038I After 0.17 seconds - Feasibility pump exiting with objective of 0 - took 0.06 seconds
# Cbc0012I Integer solution of 0 found by feasibility pump after 0 iterations and 0 nodes (0.26 seconds)
# Cbc0001I Search completed - best objective 0, took 0 iterations and 0 nodes (0.26 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.61
# Time (Wallclock seconds):       0.64
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.62   (Wallclock seconds):       0.66
# [*********************100%%**********************]  35 of 35 completed
# [*********************100%%**********************]  1 of 1 completed
# Ticker        SP_500  Optimized Portfolio
# Date
# 2023-03-01  1.000000             1.000000
# 2023-04-01  1.035052             1.039673
# 2023-05-01  1.050207             1.040838
# 2023-06-01  1.052814             1.051704
# 2023-07-01  1.120960             1.120231
# 2023-08-01  1.155866             1.170409
# 2023-09-01  1.135388             1.143553
# 2023-10-01  1.080073             1.084424
# 2023-11-01  1.056333             1.049101
# 2023-12-01  1.150536             1.153054
# 2024-01-01  1.201423             1.216624
# 2024-02-01  1.220521             1.222655

# %%
simulator(1.71,0.30,0.8,'2018-05-01','2021-06-01',1000000,50) 
port_betas
# Out:
# [*********************100%%**********************]  501 of 501 completed
#
# 8 Failed downloads:
# ['KVUE', 'GEHC', 'GEV', 'SOLV', 'CEG', 'VLTO']: Exception("%ticker%: Data doesn't exist for startDate = 1525147200, endDate = 1622520000")
# ['BF.B']: Exception('%ticker%: No price data found, symbol may be delisted (1mo 2018-05-01 -> 2021-06-01)')
# ['BRK.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  484 of 484 completed
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/l4/hkz5jfdx3t581gbl8x7mfqs40000gn/T/9c471d7413e64b19a83412b6b1c54fba-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/l4/hkz5jfdx3t581gbl8x7mfqs40000gn/T/9c471d7413e64b19a83412b6b1c54fba-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 2501 COLUMNS
# At line 45200 RHS
# At line 47697 BOUNDS
# At line 48182 ENDATA
# Problem MODEL has 2496 rows, 2456 columns and 41694 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.221365 - 0.08 seconds
# Cgl0004I processed model has 1044 rows, 1488 columns (484 integer (484 of which binary)) and 38790 elements
# Cbc0038I Initial state - 27 integers unsatisfied sum - 1
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 3.2267 iterations 584
# Cbc0038I Solution found of 3.2267
# Cbc0038I Relaxing continuous gives 3.2267
# Cbc0038I Before mini branch and bound, 456 integers at bound fixed and 912 continuous
# Cbc0038I Full problem 1044 rows 1488 columns, reduced to 103 rows 92 columns
# Cbc0038I Mini branch and bound improved solution from 3.2267 to 0.221365 (0.19 seconds)
# Cbc0038I Freeing continuous variables gives a solution of 0.221365
# Cbc0038I After 0.20 seconds - Feasibility pump exiting with objective of 0.221365 - took 0.06 seconds
# Cbc0012I Integer solution of 0.22136521 found by feasibility pump after 0 iterations and 0 nodes (0.25 seconds)
# Cbc0001I Search completed - best objective 0.221365207510481, took 0 iterations and 0 nodes (0.25 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0.221365 to 0.221365
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.22136521
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.35
# Time (Wallclock seconds):       0.38
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.37   (Wallclock seconds):       0.41
#           SP_500  Target  Optimization  Abs. Diff
# Mkt-RF  0.969685    1.71      1.625159     0.0848
# SMB    -0.172165    0.30      0.316681     0.0167
# HML     0.036521    0.80      0.725837     0.0742

# %%
sharess.to_excel('shares1.xlsx')

# %%
#future price function

def get_last_future_price(symbol):
    future = yf.Ticker(symbol)
    data = future.history(period="1d")
    last_price = data['Close'].iloc[-1]
    return last_price

# %%
#Adjusting tickers list as some tickers will not be included in the monthly_data if there is no data for test date range
tickers = list(monthly_data.columns[:-1])
tick_index = tickers + ['SP_500']
init = 1        #Initial Common Value (Can be thought of Initial Investment of $1 USD in each stock)
global performance
performance = pd.DataFrame(np.ones((len(monthly_data),len(monthly_data.columns))), index = monthly_data.index, columns = monthly_data.columns)
for j in range(1,len(monthly_data.index)):
    performance.iloc[j] = performance.iloc[j-1]*(monthly_data.iloc[j-1][monthly_data.columns]+init)
plt.style.use('ggplot')
fig = plt.figure(figsize=(12,8), dpi=100)
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])   # left, bottom, width, height (range 0 to 1)

# Plot on that set of axes
for i in range(0,len(monthly_data.columns)):
        axes.plot(performance.index, performance.iloc[:,i], linewidth=1)

#axes.set_prop_cycle(cycler)
axes.set_xlabel('Date')
axes.set_ylabel('Performance')
axes.set_title('In Sample Monthly Performance of $1 USD by Ticker')
axes.legend(tick_index, bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0, fontsize='small')

plt.show()
